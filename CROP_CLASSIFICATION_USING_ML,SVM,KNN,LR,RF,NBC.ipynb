# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Crop_Recommendation.csv')

# %%
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0           90        42.0         43    20.879744  82.002744  6.502985
# 1           85        58.0         41    21.770462  80.319644  7.038096
# 2           60        55.0         44    23.004459  82.320763  7.840207
# 3           74        35.0         40    26.491096  80.158363  6.980401
# 4           78        42.0         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107        34.0         32    26.774637  66.413269  6.780064
# 2196        99        15.0         27    27.417112  56.636362  6.086922
# 2197       118        33.0         30    24.131797  67.225123  6.362608
# 2198       117        32.0         34    26.272418  52.127394  6.758793
# 2199       104        18.0         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop
# 0     202.935536    Rice
# 1     226.655537    Rice
# ...

# %%
df.head(50)
# Out:
#     Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0         90        42.0         43    20.879744  82.002744  6.502985
# 1         85        58.0         41    21.770462  80.319644  7.038096
# 2         60        55.0         44    23.004459  82.320763  7.840207
# 3         74        35.0         40    26.491096  80.158363  6.980401
# 4         78        42.0         42    20.130175  81.604873  7.628473
# 5         69        37.0         42    23.058049  83.370118  7.073454
# 6         69        55.0         38    22.708838  82.639414  5.700806
# 7         94        53.0         40    20.277744  82.894086  5.718627
# 8         89        54.0         38    24.515881  83.535216  6.685346
# 9         68        58.0         38    23.223974  83.033227  6.336254
# 10        91        53.0         40    26.527235  81.417538  5.386168
# 11        90        46.0         42    23.978982  81.450616  7.502834
# ...

# %%
df.tail(3)
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 2197       118        33.0         30    24.131797  67.225123  6.362608
# 2198       117        32.0         34    26.272418  52.127394  6.758793
# 2199       104        18.0         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop
# 2197  173.322839  Coffee
# 2198  127.175293  Coffee
# 2199  140.937041  Coffee

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nitrogen     2200 non-null   int64
#  1   Phosphorus   2199 non-null   float64
#  2   Potassium    2200 non-null   int64
#  3   Temperature  2193 non-null   float64
#  4   Humidity     2192 non-null   float64
#  5   pH_Value     2194 non-null   float64
#  6   Rainfall     2195 non-null   float64
#  7   Crop         2200 non-null   object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 137.6+ KB

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.describe()
# Out:
#           Nitrogen   Phosphorus    Potassium  Temperature     Humidity  \
# count  2200.000000  2199.000000  2200.000000  2193.000000  2192.000000
# mean     50.551818    53.376535    48.149091    25.616298    71.483751
# std      36.917334    32.987026    50.647931     5.067266    22.229120
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.766430    60.261953
# 50%      37.000000    51.000000    32.000000    25.601540    80.464995
# 75%      84.250000    68.000000    49.000000    28.562122    89.935185
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#           pH_Value     Rainfall
# count  2194.000000  2195.000000
# mean      6.469140   103.488279
# std       0.773323    55.004364
# min       3.504752    20.211267
# 25%       5.970677    64.544549
# 50%       6.426829    94.781896
# 75%       6.923909   124.402507
# max       9.935091   298.560117

# %%
df.isnull().sum()
# Out:
# Nitrogen       0
# Phosphorus     1
# Potassium      0
# Temperature    7
# Humidity       8
# pH_Value       6
# Rainfall       5
# Crop           0
# dtype: int64

# %%
v=df['Crop'].values

# %%
print(v)
# Out:
# ['Rice' 'Rice' 'Rice' ... 'Coffee' 'Coffee' 'Coffee']

# %%
a=df['Nitrogen']
sns.lineplot(a)
# Out:
# <Axes: ylabel='Nitrogen'>

# %%
b=df['Potassium']
c=df['Temperature']
sns.scatterplot(x=b,y=c,data=df)
# Out:
# <Axes: xlabel='Potassium', ylabel='Temperature'>

# %%
d=df['Rainfall']
sns.barplot(d)
# Out:
# <Axes: ylabel='Rainfall'>

# %%
sns.distplot(a)
# Out:
# <ipython-input-178-f134c0697e25>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a)
# <Axes: xlabel='Nitrogen', ylabel='Density'>

# %%
sns.boxplot(c)
# Out:
# <Axes: ylabel='Temperature'>

# %%
from sklearn.preprocessing import LabelEncoder
tap=LabelEncoder()
df['Crop']=tap.fit_transform(df['Crop'])

# %%
u=df.corr()
sns.heatmap(u,annot=True)
# Out:
# <Axes: >

# %%
df=df.dropna()

# %%
x=df.drop(['Crop'],axis=1)
y=df['Crop']

# %%
x
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0           90        42.0         43    20.879744  82.002744  6.502985
# 1           85        58.0         41    21.770462  80.319644  7.038096
# 2           60        55.0         44    23.004459  82.320763  7.840207
# 3           74        35.0         40    26.491096  80.158363  6.980401
# 4           78        42.0         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107        34.0         32    26.774637  66.413269  6.780064
# 2196        99        15.0         27    27.417112  56.636362  6.086922
# 2197       118        33.0         30    24.131797  67.225123  6.362608
# 2198       117        32.0         34    26.272418  52.127394  6.758793
# 2199       104        18.0         30    23.603016  60.396475  6.779833
#
#         Rainfall
# 0     202.935536
# 1     226.655537
# 2     263.964248
# 3     242.864034
# ...

# %%
y
# Out:
# 0       20
# 1       20
# 2       20
# 3       20
# 4       20
#         ..
# 2195     5
# 2196     5
# 2197     5
# 2198     5
# 2199     5
# Name: Crop, Length: 2173, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=95)

# %%
x_train
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 1405        81        25.0         49    29.868958  93.251032  6.076460
# 1142        34        38.0         31    35.377756  45.581100  6.454045
# 50          60        36.0         43    23.431219  83.063101  5.286204
# 297         36        56.0         83    18.897802  19.761829  7.452671
# 1769        54        67.0         52    35.676673  93.306419  6.586107
# ...        ...         ...        ...          ...        ...       ...
# 358         12        63.0         17    18.358923  19.377034  5.717143
# 359         27        56.0         20    19.259754  20.513470  5.542690
# 1815         0        19.0         33    27.132601  95.237980  6.234458
# 2009        74        40.0         40    25.138428  83.120539  6.386260
# 2193       116        38.0         34    23.292503  50.045570  6.020947
#
#         Rainfall
# 1405   26.262430
# 1142   97.415864
# 50    219.904835
# 297    69.095125
# ...

# %%
x_test
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 1205         2       123.0        198    39.648519  82.210799  6.253035
# 1339        80        16.0         46    25.504055  81.402974  6.940236
# 1037       119        72.0         55    25.990695  83.339831  6.220644
# 1170        18        20.0         26    31.665247  51.985946  5.435841
# 1373       104        23.0         47    26.982128  86.700683  6.770434
# ...        ...         ...        ...          ...        ...       ...
# 2139       113        21.0         33    26.022414  55.832890  7.277423
# 1906       113        41.0         20    25.001719  80.539658  7.256878
# 1710        58        51.0         47    42.134740  91.704454  6.757471
# 1236         3       134.0        199    20.283702  81.322357  5.817178
# 1621         0        25.0         14    19.335168  91.979789  6.361671
#
#         Rainfall
# 1205   70.399061
# 1339   48.478333
# 1037  112.077715
# 1170   89.980243
# ...

# %%
y_train
# Out:
# 1405    15
# 1142    12
# 50      20
# 297      3
# 1769    17
#         ..
# 358      9
# 359      9
# 1815     4
# 2009     8
# 2193     5
# Name: Crop, Length: 1629, dtype: int64

# %%
y_test
# Out:
# 1205     7
# 1339    21
# 1037     1
# 1170    12
# 1373    21
#         ..
# 2139     5
# 1906     6
# 1710    17
# 1236     7
# 1621    16
# Name: Crop, Length: 544, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
rap=DecisionTreeClassifier(criterion='entropy')
rap.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred=rap.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.9908088235294118

# %%
from sklearn.svm import SVC
wat=SVC(kernel='linear')
wat.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=wat.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.9908088235294118

# %%
from sklearn.neighbors import KNeighborsClassifier
red=KNeighborsClassifier(n_neighbors=7)
red.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=red.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.9797794117647058

# %%
from sklearn.ensemble import RandomForestClassifier
wed=RandomForestClassifier(n_estimators=100,n_jobs=1,max_depth=7,random_state=50,oob_score=True,criterion='entropy')
wed.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=7, n_jobs=1,
#                        oob_score=True, random_state=50)

# %%
y_pred=wed.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 1.0

# %%
from sklearn.linear_model import LogisticRegression
zat=LogisticRegression()
zat.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=zat.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.9669117647058824

# %%
from sklearn.naive_bayes import GaussianNB
rip=GaussianNB()
rip.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=rip.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 1.0

# %%
from sklearn.tree import export_graphviz
import graphviz
graphviz.Source(export_graphviz(rap,feature_names=x.columns))
