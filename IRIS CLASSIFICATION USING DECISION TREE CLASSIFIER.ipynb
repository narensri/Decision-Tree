# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.head(2)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa

# %%
df.tail(3)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.shape
# Out:
# (150, 6)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
g=df['SepalLengthCm']
plt.plot(g)

# %%
t=df['SepalWidthCm']
z=df['PetalWidthCm']
plt.scatter(t,z)

# %%
plt.bar(g,height=70)
# Out:
# <BarContainer object of 150 artists>

# %%
plt.bar(t,z)
# Out:
# <BarContainer object of 150 artists>

# %%
plt.hist(t)
# Out:
# (array([ 4.,  7., 22., 24., 38., 31.,  9., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pie(g)
# Out:
# ([<matplotlib.patches.Wedge at 0x79bd4ca6b250>,
#   <matplotlib.patches.Wedge at 0x79bd4ca6b160>,
#   <matplotlib.patches.Wedge at 0x79bd4ca6bb20>,
#   <matplotlib.patches.Wedge at 0x79bd4ca6bfa0>,
#   <matplotlib.patches.Wedge at 0x79bd4ca9c460>,
#   <matplotlib.patches.Wedge at 0x79bd4ca9c9d0>,
#   <matplotlib.patches.Wedge at 0x79bd4ca9cd90>,
#   <matplotlib.patches.Wedge at 0x79bd4ca9d210>,
#   <matplotlib.patches.Wedge at 0x79bd4ca9d690>,
#   <matplotlib.patches.Wedge at 0x79bd4ca9db10>,
#   <matplotlib.patches.Wedge at 0x79bd4ca6b220>,
#   <matplotlib.patches.Wedge at 0x79bd4ca9e3e0>,
#   <matplotlib.patches.Wedge at 0x79bd4ca9e860>,
#   <matplotlib.patches.Wedge at 0x79bd4ca9ece0>,
#   <matplotlib.patches.Wedge at 0x79bd4ca9f160>,
#   <matplotlib.patches.Wedge at 0x79bd4ca9f5e0>,
#   <matplotlib.patches.Wedge at 0x79bd4ca9fa60>,
#   <matplotlib.patches.Wedge at 0x79bd4ca9fee0>,
#   <matplotlib.patches.Wedge at 0x79bd4cad83a0>,
#   <matplotlib.patches.Wedge at 0x79bd4cad8820>,
#   <matplotlib.patches.Wedge at 0x79bd4cad8ca0>,
#   <matplotlib.patches.Wedge at 0x79bd4cad9060>,
#   <matplotlib.patches.Wedge at 0x79bd4cad9570>,
#   <matplotlib.patches.Wedge at 0x79bd4cad99f0>,
#   <matplotlib.patches.Wedge at 0x79bd4cad9e70>,
#   <matplotlib.patches.Wedge at 0x79bd4cada2f0>,
#   <matplotlib.patches.Wedge at 0x79bd4cada770>,
#   <matplotlib.patches.Wedge at 0x79bd4cadabf0>,
#   <matplotlib.patches.Wedge at 0x79bd4cadb070>,
#   <matplotlib.patches.Wedge at 0x79bd4cadb4f0>,
#   <matplotlib.patches.Wedge at 0x79bd4cadb970>,
#   <matplotlib.patches.Wedge at 0x79bd4cadbdf0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb082b0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb08730>,
#   <matplotlib.patches.Wedge at 0x79bd4cb08bb0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb09030>,
#   <matplotlib.patches.Wedge at 0x79bd4cb094b0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb09930>,
#   <matplotlib.patches.Wedge at 0x79bd4cb09db0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb0a230>,
#   <matplotlib.patches.Wedge at 0x79bd4cb0a6b0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb0ab30>,
#   <matplotlib.patches.Wedge at 0x79bd4cb0afb0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb0b430>,
#   <matplotlib.patches.Wedge at 0x79bd4cb0b8b0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb0bd30>,
#   <matplotlib.patches.Wedge at 0x79bd4cb441f0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb44670>,
#   <matplotlib.patches.Wedge at 0x79bd4cb44af0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb44f70>,
#   <matplotlib.patches.Wedge at 0x79bd4cb453f0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb45870>,
#   <matplotlib.patches.Wedge at 0x79bd4cb45cf0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb46170>,
#   <matplotlib.patches.Wedge at 0x79bd4cb465f0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb46a70>,
#   <matplotlib.patches.Wedge at 0x79bd4cb46fe0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb473a0>,
#   <matplotlib.patches.Wedge at 0x79bd4cb47820>,
#   <matplotlib.patches.Wedge at 0x79bd4cb47ca0>,
#   <matplotlib.patches.Wedge at 0x79bd4c98c160>,
#   <matplotlib.patches.Wedge at 0x79bd4c98c5e0>,
#   <matplotlib.patches.Wedge at 0x79bd4c98ca60>,
#   <matplotlib.patches.Wedge at 0x79bd4c98cee0>,
#   <matplotlib.patches.Wedge at 0x79bd4c98d360>,
#   <matplotlib.patches.Wedge at 0x79bd4c98d7e0>,
#   <matplotlib.patches.Wedge at 0x79bd4c98dc60>,
#   <matplotlib.patches.Wedge at 0x79bd4c98e0e0>,
#   <matplotlib.patches.Wedge at 0x79bd4c98e560>,
#   <matplotlib.patches.Wedge at 0x79bd4c98e9e0>,
#   <matplotlib.patches.Wedge at 0x79bd4c98ee60>,
#   <matplotlib.patches.Wedge at 0x79bd4c98f2e0>,
#   <matplotlib.patches.Wedge at 0x79bd4c98f760>,
#   <matplotlib.patches.Wedge at 0x79bd4c98fbe0>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c00a0>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c0520>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c09a0>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c0e50>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c12d0>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c1750>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c1bd0>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c2050>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c24d0>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c2950>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c2dd0>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c3250>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c36d0>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c3b50>,
#   <matplotlib.patches.Wedge at 0x79bd4c9c3fd0>,
#   <matplotlib.patches.Wedge at 0x79bd4c9f8490>,
#   <matplotlib.patches.Wedge at 0x79bd4c9f8910>,
#   <matplotlib.patches.Wedge at 0x79bd4c9f8d90>,
#   <matplotlib.patches.Wedge at 0x79bd4c9f9210>,
#   <matplotlib.patches.Wedge at 0x79bd4c9f9690>,
#   <matplotlib.patches.Wedge at 0x79bd4c9f9b10>,
#   <matplotlib.patches.Wedge at 0x79bd4c9f9f90>,
#   <matplotlib.patches.Wedge at 0x79bd4c9fa410>,
#   <matplotlib.patches.Wedge at 0x79bd4c9fa890>,
#   <matplotlib.patches.Wedge at 0x79bd4c9fad10>,
#   <matplotlib.patches.Wedge at 0x79bd4c9fb190>,
#   <matplotlib.patches.Wedge at 0x79bd4c9fb610>,
#   <matplotlib.patches.Wedge at 0x79bd4c9fba90>,
#   <matplotlib.patches.Wedge at 0x79bd4c9fbf10>,
#   <matplotlib.patches.Wedge at 0x79bd4ca383d0>,
#   <matplotlib.patches.Wedge at 0x79bd4ca38850>,
#   <matplotlib.patches.Wedge at 0x79bd4ca38cd0>,
#   <matplotlib.patches.Wedge at 0x79bd4ca39150>,
#   <matplotlib.patches.Wedge at 0x79bd4ca395d0>,
#   <matplotlib.patches.Wedge at 0x79bd4ca39a50>,
#   <matplotlib.patches.Wedge at 0x79bd4ca39ed0>,
#   <matplotlib.patches.Wedge at 0x79bd4ca3a350>,
#   <matplotlib.patches.Wedge at 0x79bd4ca3a7d0>,
#   <matplotlib.patches.Wedge at 0x79bd4ca3ac50>,
#   <matplotlib.patches.Wedge at 0x79bd4ca3b0d0>,
#   <matplotlib.patches.Wedge at 0x79bd4ca3b640>,
#   <matplotlib.patches.Wedge at 0x79bd4ca3ba00>,
#   <matplotlib.patches.Wedge at 0x79bd4ca3be80>,
#   <matplotlib.patches.Wedge at 0x79bd4c878340>,
#   <matplotlib.patches.Wedge at 0x79bd4c8787c0>,
#   <matplotlib.patches.Wedge at 0x79bd4c878c40>,
#   <matplotlib.patches.Wedge at 0x79bd4c8790c0>,
#   <matplotlib.patches.Wedge at 0x79bd4c879540>,
#   <matplotlib.patches.Wedge at 0x79bd4c879930>,
#   <matplotlib.patches.Wedge at 0x79bd4c879e10>,
#   <matplotlib.patches.Wedge at 0x79bd4c87a290>,
#   <matplotlib.patches.Wedge at 0x79bd4c87a710>,
#   <matplotlib.patches.Wedge at 0x79bd4c87ab90>,
#   <matplotlib.patches.Wedge at 0x79bd4c87b010>,
#   <matplotlib.patches.Wedge at 0x79bd4c87b580>,
#   <matplotlib.patches.Wedge at 0x79bd4c87b940>,
#   <matplotlib.patches.Wedge at 0x79bd4c87bdc0>,
#   <matplotlib.patches.Wedge at 0x79bd4c8b8280>,
#   <matplotlib.patches.Wedge at 0x79bd4c8b8730>,
#   <matplotlib.patches.Wedge at 0x79bd4c8b8bb0>,
#   <matplotlib.patches.Wedge at 0x79bd4c8b9030>,
#   <matplotlib.patches.Wedge at 0x79bd4c8b94b0>,
#   <matplotlib.patches.Wedge at 0x79bd4c8b9930>,
#   <matplotlib.patches.Wedge at 0x79bd4c8b9db0>,
#   <matplotlib.patches.Wedge at 0x79bd4c8ba230>,
#   <matplotlib.patches.Wedge at 0x79bd4c8ba6b0>,
#   <matplotlib.patches.Wedge at 0x79bd4c8bab30>,
#   <matplotlib.patches.Wedge at 0x79bd4c8bafb0>,
#   <matplotlib.patches.Wedge at 0x79bd4c8bb430>,
#   <matplotlib.patches.Wedge at 0x79bd4c8bb8b0>,
#   <matplotlib.patches.Wedge at 0x79bd4c8bbd30>,
#   <matplotlib.patches.Wedge at 0x79bd4c8f41f0>,
#   <matplotlib.patches.Wedge at 0x79bd4c8f46a0>,
#   <matplotlib.patches.Wedge at 0x79bd4c8f4b20>,
#   <matplotlib.patches.Wedge at 0x79bd4c8f4fa0>,
#   <matplotlib.patches.Wedge at 0x79bd4c8f5420>],
#  [Text(1.0998162248289156, 0.020106506486022895, ''),
#   Text(1.0983893303845753, 0.059505284616782936, ''),
#   Text(1.0956920682406373, 0.0972568331509659, ''),
#   Text(1.091842090596001, 0.1337192925607762, ''),
#   Text(1.0865955946241563, 0.17120167564418406, ''),
#   Text(1.0794604973247504, 0.21157749104146875, ''),
#   Text(1.0711853524326178, 0.25012385078958144, ''),
#   Text(1.061946535861541, 0.2868266984987159, ''),
#   Text(1.051681945368862, 0.322436173195822, ''),
#   Text(1.0403517900227819, 0.35730680513585744, ''),
#   Text(1.0264549462634536, 0.39546206302411735, ''),
#   Text(1.0113144459682202, 0.4327159476792971, ''),
#   Text(0.9958295372217366, 0.4672510383046166, ''),
#   Text(0.9800624176136543, 0.4994773844542706, ''),
#   Text(0.9613427184591771, 0.5346215274991455, ''),
#   Text(0.9384959352390051, 0.5737816479636355, ''),
#   Text(0.9149313166628202, 0.6106559471499793, ''),
#   Text(0.8913070906159923, 0.644648485779386, ''),
#   Text(0.8656913561814885, 0.6786593223648043, ''),
#   Text(0.8387785851090395, 0.7116533462033873, ''),
#   Text(0.8114081835347964, 0.7427090680022442, ''),
#   Text(0.7828886692191259, 0.7727129684483793, ''),
#   Text(0.7555559028440736, 0.7994593658701341, ''),
#   Text(0.7273099441970501, 0.8252395077019059, ''),
#   Text(0.6975754143028088, 0.8505225107898468, ''),
#   Text(0.6672761298553448, 0.8744956069216548, ''),
#   Text(0.635510182136509, 0.8978456484278471, ''),
#   Text(0.6022682079207882, 0.9204743373543244, ''),
#   Text(0.7561288060575763, -0.7989175355754463, ''),
#   Text(0.7916996875179442, -0.7636829216265019, ''),
#   Text(0.8248483415991666, -0.7277535388860056, ''),
#   Text(0.8598214437517994, -0.686080960867281, ''),
#   Text(0.8931518908096354, -0.6420901026671983, ''),
#   Text(0.9214445262374452, -0.6007828102293293, ''),
#   Text(0.9472273986527301, -0.5592497252941497, ''),
#   Text(0.9720637672700949, -0.5148708890204134, ''),
#   Text(0.9959969471014745, -0.46689407938476035, ''),
#   Text(1.017563958091165, -0.41780807937836933, ''),
#   Text(1.0355219426017486, -0.37107183454191334, ''),
#   Text(1.0512185867541617, -0.3239436414912063, ''),
#   Text(1.0656568538140117, -0.2727186644130219, ''),
#   Text(1.0775213193607978, -0.2212415113014868, ''),
#   Text(1.0866568858167311, -0.17081221416246548, ''),
#   Text(1.0933473116973982, -0.12079592710051475, ''),
#   Text(1.097711488457558, -0.07091888400343593, ''),
#   Text(1.0997540499435292, -0.02326004369740927, '')])

# %%
sns.lineplot(t)
# Out:
# <Axes: ylabel='SepalWidthCm'>

# %%
sns.scatterplot(x=z,y=g,data=df)
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='SepalLengthCm'>

# %%
sns.barplot(g)
# Out:
# <Axes: ylabel='SepalLengthCm'>

# %%
sns.barplot(x=g,y=t,data=df)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
q=df['PetalLengthCm']
sns.distplot(q)
# Out:
# <ipython-input-22-40d336e6222b>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(q)
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %%
sns.pairplot(df)

# %%
sns.boxplot(g)
# Out:
# <Axes: ylabel='SepalLengthCm'>

# %%
a=df.corr()
sns.heatmap(a,annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-5d4bcd71c8a2> in <cell line: 1>()
# ----> 1 a=df.corr()
#       2 sns.heatmap(a,annot=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10702         cols = data.columns
#   10703         idx = cols.copy()
# > 10704         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10705
#   10706         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1887         if dtype is not None:
#    1888             dtype = np.dtype(dtype)
# -> 1889         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890         if result.dtype is not dtype:
#    1891             result = np.array(result, dtype=dtype, copy=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in as_array(self, dtype, copy, na_value)
#    1654                 arr.flags.writeable = False
#    1655         else:
# -> 1656             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657             # The underlying data was copied within _interleave, so no need
#    1658             # to further copy if copy=True or setting na_value
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#    1713             else:
#    1714                 arr = blk.get_values(dtype)
# -> 1715             result[rl.indexer] = arr
#    1716             itemmask[rl.indexer] = 1
#    1717
#
# ValueError: could not convert string to float: 'Iris-setosa'

# %%
x=df.drop('Species',axis=1)
y=df['Species']

# %%
x
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=95)

# %%
x_train
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 78    79            6.0           2.9            4.5           1.5
# 113  114            5.7           2.5            5.0           2.0
# 134  135            6.1           2.6            5.6           1.4
# 109  110            7.2           3.6            6.1           2.5
# 124  125            6.7           3.3            5.7           2.1
# ..   ...            ...           ...            ...           ...
# 2      3            4.7           3.2            1.3           0.2
# 5      6            5.4           3.9            1.7           0.4
# 118  119            7.7           2.6            6.9           2.3
# 19    20            5.1           3.8            1.5           0.3
# 41    42            4.5           2.3            1.3           0.3
#
# [120 rows x 5 columns]

# %%
x_test
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 101  102            5.8           2.7            5.1           1.9
# 122  123            7.7           2.8            6.7           2.0
# 108  109            6.7           2.5            5.8           1.8
# 10    11            5.4           3.7            1.5           0.2
# 48    49            5.3           3.7            1.5           0.2
# 145  146            6.7           3.0            5.2           2.3
# 88    89            5.6           3.0            4.1           1.3
# 114  115            5.8           2.8            5.1           2.4
# 21    22            5.1           3.7            1.5           0.4
# 93    94            5.0           2.3            3.3           1.0
# 47    48            4.6           3.2            1.4           0.2
# 73    74            6.1           2.8            4.7           1.2
# 18    19            5.7           3.8            1.7           0.3
# 141  142            6.9           3.1            5.1           2.3
# 146  147            6.3           2.5            5.0           1.9
# 115  116            6.4           3.2            5.3           2.3
# 57    58            4.9           2.4            3.3           1.0
# 56    57            6.3           3.3            4.7           1.6
# 138  139            6.0           3.0            4.8           1.8
# 66    67            5.6           3.0            4.5           1.5
# 72    73            6.3           2.5            4.9           1.5
# 112  113            6.8           3.0            5.5           2.1
# 54    55            6.5           2.8            4.6           1.5
# 16    17            5.4           3.9            1.3           0.4
# 38    39            4.4           3.0            1.3           0.2
# 0      1            5.1           3.5            1.4           0.2
# 82    83            5.8           2.7            3.9           1.2
# 92    93            5.8           2.6            4.0           1.2
# 15    16            5.7           4.4            1.5           0.4
# 70    71            5.9           3.2            4.8           1.8

# %%
y_train
# Out:
# 78     Iris-versicolor
# 113     Iris-virginica
# 134     Iris-virginica
# 109     Iris-virginica
# 124     Iris-virginica
#             ...
# 2          Iris-setosa
# 5          Iris-setosa
# 118     Iris-virginica
# 19         Iris-setosa
# 41         Iris-setosa
# Name: Species, Length: 120, dtype: object

# %%
y_test
# Out:
# 101     Iris-virginica
# 122     Iris-virginica
# 108     Iris-virginica
# 10         Iris-setosa
# 48         Iris-setosa
# 145     Iris-virginica
# 88     Iris-versicolor
# 114     Iris-virginica
# 21         Iris-setosa
# 93     Iris-versicolor
# 47         Iris-setosa
# 73     Iris-versicolor
# 18         Iris-setosa
# 141     Iris-virginica
# 146     Iris-virginica
# 115     Iris-virginica
# 57     Iris-versicolor
# 56     Iris-versicolor
# 138     Iris-virginica
# 66     Iris-versicolor
# 72     Iris-versicolor
# 112     Iris-virginica
# 54     Iris-versicolor
# 16         Iris-setosa
# 38         Iris-setosa
# 0          Iris-setosa
# 82     Iris-versicolor
# 92     Iris-versicolor
# 15         Iris-setosa
# 70     Iris-versicolor
# Name: Species, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier()

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 1.0

# %%
from sklearn.tree import export_graphviz
import graphviz
graphviz.Source(export_graphviz(clf,feature_names=x.columns))
