# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
df.tail(2)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.shape
# Out:
# (768, 9)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
a=df['Age']
sns.lineplot(a)
# Out:
# <Axes: ylabel='Age'>

# %%
b=df['Glucose']
c=df['BMI']
sns.scatterplot(x=b,y=c,data=df)
# Out:
# <Axes: xlabel='Glucose', ylabel='BMI'>

# %%
d=df['Insulin']
sns.barplot(d)
# Out:
# <Axes: ylabel='Insulin'>

# %%
sns.distplot(c)
# Out:
# <ipython-input-16-a8556bb5cad6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c)
# <Axes: xlabel='BMI', ylabel='Density'>

# %%
j=df.corr()
sns.heatmap(j,annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(b)
# Out:
# <Axes: ylabel='Glucose'>

# %%
x=df.drop('Outcome',axis=1)
y=df['Outcome']

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=95)

# %%
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 448            0      104             64             37       64  33.6
# 647            0      179             50             36      159  37.8
# 365            5       99             54             28       83  34.0
# 752            3      108             62             24        0  26.0
# 446            1      100             72             12       70  25.3
# ..           ...      ...            ...            ...      ...   ...
# 420            1      119             88             41      170  45.3
# 118            4       97             60             23        0  28.2
# 531            0      107             76              0        0  45.3
# 297            0      126             84             29      215  30.7
# 406            4      115             72              0        0  28.9
#
#      DiabetesPedigreeFunction  Age
# 448                     0.510   22
# 647                     0.455   22
# ...

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 435            0      141              0              0        0  42.4
# 615            3      106             72              0        0  25.8
# 598            1      173             74              0        0  36.8
# 195            5      158             84             41      210  39.4
# 599            1      109             38             18      120  23.1
# ..           ...      ...            ...            ...      ...   ...
# 464           10      115             98              0        0  24.0
# 389            3      100             68             23       81  31.6
# 319            6      194             78              0        0  23.5
# 416            1       97             68             21        0  27.2
# 231            6      134             80             37      370  46.2
#
#      DiabetesPedigreeFunction  Age
# 435                     0.205   29
# 615                     0.207   27
# ...

# %%
y_train
# Out:
# 448    1
# 647    1
# 365    0
# 752    0
# 446    0
#       ..
# 420    0
# 118    0
# 531    0
# 297    0
# 406    1
# Name: Outcome, Length: 614, dtype: int64

# %%
y_test
# Out:
# 435    1
# 615    0
# 598    1
# 195    1
# 599    0
#       ..
# 464    0
# 389    0
# 319    1
# 416    0
# 231    1
# Name: Outcome, Length: 154, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
tap=DecisionTreeClassifier(criterion='entropy')
tap.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred=tap.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.7792207792207793

# %%
from sklearn.tree import export_graphviz
import graphviz
graphviz.Source(export_graphviz(tap,feature_names=x.columns))

# %%
from sklearn.svm import SVC
bad=SVC(kernel='linear')
bad.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=bad.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.8051948051948052

# %%
from sklearn.ensemble import RandomForestClassifier
rap=RandomForestClassifier(max_depth=7 ,n_estimators=120,n_jobs=1,random_state=50,oob_score=False)
rap.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=7, n_estimators=120, n_jobs=1, random_state=50)

# %%
y_pred=rap.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.8051948051948052

# %%
from sklearn.linear_model import LogisticRegression
vip=LogisticRegression()
vip.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=vip.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.8181818181818182

# %%
from sklearn.neighbors import KNeighborsClassifier
rip=KNeighborsClassifier(n_neighbors=17)
rip.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=17)

# %%
y_pred=rip.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.7272727272727273
