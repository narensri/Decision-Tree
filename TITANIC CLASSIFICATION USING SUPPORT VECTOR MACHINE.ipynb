# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df=df.drop(['Name','Sex','Ticket','Embarked','Cabin','PassengerId'],axis=1)

# %%
a=df['Survived']
sns.lineplot(a)
# Out:
# <Axes: ylabel='Survived'>

# %%
b=df['Parch']
c=df['SibSp']
sns.scatterplot(x=b,y=c,data=df)
# Out:
# <Axes: xlabel='Parch', ylabel='SibSp'>

# %%
d=df['Pclass']
sns.barplot(d)
# Out:
# <Axes: ylabel='Pclass'>

# %%
sns.displot(a)

# %%
sns.pairplot(df)

# %%
s=df.corr()
sns.heatmap(s,annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(d)
# Out:
# <Axes: ylabel='Pclass'>

# %%
df=df.dropna()

# %%
x=df.drop('Survived',axis=1)
y=df['Survived']

# %%
x
# Out:
#      Pclass   Age  SibSp  Parch     Fare
# 0         3  22.0      1      0   7.2500
# 1         1  38.0      1      0  71.2833
# 2         3  26.0      0      0   7.9250
# 3         1  35.0      1      0  53.1000
# 4         3  35.0      0      0   8.0500
# ..      ...   ...    ...    ...      ...
# 885       3  39.0      0      5  29.1250
# 886       2  27.0      0      0  13.0000
# 887       1  19.0      0      0  30.0000
# 889       1  26.0      0      0  30.0000
# 890       3  32.0      0      0   7.7500
#
# [714 rows x 5 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 714, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=95)

# %%
x_train
# Out:
#      Pclass   Age  SibSp  Parch      Fare
# 712       1  48.0      1      0   52.0000
# 393       1  23.0      1      0  113.2750
# 254       3  41.0      0      2   20.2125
# 136       1  19.0      0      2   26.2833
# 590       3  35.0      0      0    7.1250
# ..      ...   ...    ...    ...       ...
# 529       2  23.0      2      1   11.5000
# 147       3   9.0      2      2   34.3750
# 672       2  70.0      0      0   10.5000
# 372       3  19.0      0      0    8.0500
# 510       3  29.0      0      0    7.7500
#
# [571 rows x 5 columns]

# %%
x_test
# Out:
#      Pclass    Age  SibSp  Parch      Fare
# 654       3  18.00      0      0    6.7500
# 366       1  60.00      1      0   75.2500
# 603       3  44.00      0      0    8.0500
# 288       2  42.00      0      0   13.0000
# 376       3  22.00      0      0    7.2500
# ..      ...    ...    ...    ...       ...
# 535       2   7.00      0      2   26.2500
# 305       1   0.92      1      2  151.5500
# 733       2  23.00      0      0   13.0000
# 685       2  25.00      1      2   41.5792
# 558       1  39.00      1      1   79.6500
#
# [143 rows x 5 columns]

# %%
y_train
# Out:
# 712    1
# 393    1
# 254    0
# 136    1
# 590    0
#       ..
# 529    0
# 147    0
# 672    0
# 372    0
# 510    1
# Name: Survived, Length: 571, dtype: int64

# %%
y_test
# Out:
# 654    0
# 366    1
# 603    0
# 288    1
# 376    1
#       ..
# 535    1
# 305    1
# 733    0
# 685    0
# 558    1
# Name: Survived, Length: 143, dtype: int64

# %%
from sklearn.svm import SVC
sip=SVC(kernel='rbf')
sip.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=sip.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.6713286713286714
