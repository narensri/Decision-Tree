# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/abalone.csv')

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.head(2)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
#
#    Shell weight  Rings
# 0          0.15     15
# 1          0.07      7

# %%
df.tail(3)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4174          0.2875         0.308      9
# 4175          0.2610         0.296     10
# 4176          0.3765         0.495     12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df=df.drop(['Sex'],axis=1)

# %%
a=df['Length']
plt.plot(a)

# %%
b=df['Diameter']
c=df['Height']
plt.scatter(b,c)

# %%
d=df['Whole weight']
plt.bar(d,height=172)
# Out:
# <BarContainer object of 4177 artists>

# %%
plt.hist(c)
# Out:
# (array([1.023e+03, 3.129e+03, 2.300e+01, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([0.   , 0.113, 0.226, 0.339, 0.452, 0.565, 0.678, 0.791, 0.904,
#         1.017, 1.13 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pie(b)
# Out:
# ([<matplotlib.patches.Wedge at 0x7de4d6a61b70>,
#   <matplotlib.patches.Wedge at 0x7de4dfc5fe80>,
#   <matplotlib.patches.Wedge at 0x7de4d6a62260>,
#   <matplotlib.patches.Wedge at 0x7de4d6a60f70>,
#   <matplotlib.patches.Wedge at 0x7de4d6a639a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a61f30>,
#   <matplotlib.patches.Wedge at 0x7de4d6a61a80>,
#   <matplotlib.patches.Wedge at 0x7de4d6a63fa0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a603a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a61060>,
#   <matplotlib.patches.Wedge at 0x7de4d6a62c80>,
#   <matplotlib.patches.Wedge at 0x7de4d6a63250>,
#   <matplotlib.patches.Wedge at 0x7de4d6aff220>,
#   <matplotlib.patches.Wedge at 0x7de4d6affdf0>,
#   <matplotlib.patches.Wedge at 0x7de4d6aff880>,
#   <matplotlib.patches.Wedge at 0x7de4d6afc3d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6afc850>,
#   <matplotlib.patches.Wedge at 0x7de4d6afccd0>,
#   <matplotlib.patches.Wedge at 0x7de4d6afd150>,
#   <matplotlib.patches.Wedge at 0x7de4d6afd5d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6afda50>,
#   <matplotlib.patches.Wedge at 0x7de4d6afded0>,
#   <matplotlib.patches.Wedge at 0x7de4d6afe350>,
#   <matplotlib.patches.Wedge at 0x7de4d6afe7d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6afed10>,
#   <matplotlib.patches.Wedge at 0x7de4d6aff100>,
#   <matplotlib.patches.Wedge at 0x7de4d6b316c0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b31180>,
#   <matplotlib.patches.Wedge at 0x7de4d6b30dc0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b307f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b30640>,
#   <matplotlib.patches.Wedge at 0x7de4d6b30040>,
#   <matplotlib.patches.Wedge at 0x7de4d6b31cc0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b32140>,
#   <matplotlib.patches.Wedge at 0x7de4d6b325c0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b32a40>,
#   <matplotlib.patches.Wedge at 0x7de4d6b32ec0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b33340>,
#   <matplotlib.patches.Wedge at 0x7de4d6b337c0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b33c40>,
#   <matplotlib.patches.Wedge at 0x7de4d6b04100>,
#   <matplotlib.patches.Wedge at 0x7de4d6b04580>,
#   <matplotlib.patches.Wedge at 0x7de4d6b04a00>,
#   <matplotlib.patches.Wedge at 0x7de4d6b04e80>,
#   <matplotlib.patches.Wedge at 0x7de4d6b05300>,
#   <matplotlib.patches.Wedge at 0x7de4d6b05780>,
#   <matplotlib.patches.Wedge at 0x7de4d6b05c00>,
#   <matplotlib.patches.Wedge at 0x7de4d6b06080>,
#   <matplotlib.patches.Wedge at 0x7de4d6b06500>,
#   <matplotlib.patches.Wedge at 0x7de4d6b06980>,
#   <matplotlib.patches.Wedge at 0x7de4d6b06e00>,
#   <matplotlib.patches.Wedge at 0x7de4d6b07280>,
#   <matplotlib.patches.Wedge at 0x7de4d6b07700>,
#   <matplotlib.patches.Wedge at 0x7de4d6b07b80>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3c8b0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3f4f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3fbb0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3ffd0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3c2b0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3c460>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3cb50>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3d060>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3d210>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3dae0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3d8a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3e0b0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3e620>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3ebc0>,
#   <matplotlib.patches.Wedge at 0x7de4d6b3eb90>,
#   <matplotlib.patches.Wedge at 0x7de4d696d7b0>,
#   <matplotlib.patches.Wedge at 0x7de4d696e110>,
#   <matplotlib.patches.Wedge at 0x7de4d696e320>,
#   <matplotlib.patches.Wedge at 0x7de4d696e7a0>,
#   <matplotlib.patches.Wedge at 0x7de4d696eaa0>,
#   <matplotlib.patches.Wedge at 0x7de4d696f1c0>,
#   <matplotlib.patches.Wedge at 0x7de4d696f6a0>,
#   <matplotlib.patches.Wedge at 0x7de4d696fd00>,
#   <matplotlib.patches.Wedge at 0x7de4d696f9d0>,
#   <matplotlib.patches.Wedge at 0x7de4d696c430>,
#   <matplotlib.patches.Wedge at 0x7de4d696c8b0>,
#   <matplotlib.patches.Wedge at 0x7de4d696cd30>,
#   <matplotlib.patches.Wedge at 0x7de4d696d1b0>,
#   <matplotlib.patches.Wedge at 0x7de4d696d630>,
#   <matplotlib.patches.Wedge at 0x7de4d6970340>,
#   <matplotlib.patches.Wedge at 0x7de4d69707c0>,
#   <matplotlib.patches.Wedge at 0x7de4d6970c40>,
#   <matplotlib.patches.Wedge at 0x7de4d69710c0>,
#   <matplotlib.patches.Wedge at 0x7de4d6971540>,
#   <matplotlib.patches.Wedge at 0x7de4d69719c0>,
#   <matplotlib.patches.Wedge at 0x7de4d6971e40>,
#   <matplotlib.patches.Wedge at 0x7de4d69722c0>,
#   <matplotlib.patches.Wedge at 0x7de4d6972740>,
#   <matplotlib.patches.Wedge at 0x7de4d6972bc0>,
#   <matplotlib.patches.Wedge at 0x7de4d6973040>,
#   <matplotlib.patches.Wedge at 0x7de4d69734c0>,
#   <matplotlib.patches.Wedge at 0x7de4d6973940>,
#   <matplotlib.patches.Wedge at 0x7de4d6973dc0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a281c0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a28670>,
#   <matplotlib.patches.Wedge at 0x7de4d6a28bb0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a291b0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a294b0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a297e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a29ba0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a29f30>,
#   <matplotlib.patches.Wedge at 0x7de4d6a2af80>,
#   <matplotlib.patches.Wedge at 0x7de4d6a2a8f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a2a2c0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a2b220>,
#   <matplotlib.patches.Wedge at 0x7de4d6a2bbe0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a2bac0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a241c0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a24640>,
#   <matplotlib.patches.Wedge at 0x7de4d6a24ac0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a24f40>,
#   <matplotlib.patches.Wedge at 0x7de4d6a25480>,
#   <matplotlib.patches.Wedge at 0x7de4d6a25870>,
#   <matplotlib.patches.Wedge at 0x7de4d6a25cf0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a26170>,
#   <matplotlib.patches.Wedge at 0x7de4d6a265f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a26a70>,
#   <matplotlib.patches.Wedge at 0x7de4d6a26ef0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a27370>,
#   <matplotlib.patches.Wedge at 0x7de4d6a277f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6a27c70>,
#   <matplotlib.patches.Wedge at 0x7de4d69b4130>,
#   <matplotlib.patches.Wedge at 0x7de4d69b45b0>,
#   <matplotlib.patches.Wedge at 0x7de4d69b4a30>,
#   <matplotlib.patches.Wedge at 0x7de4d69b4eb0>,
#   <matplotlib.patches.Wedge at 0x7de4d69b5330>,
#   <matplotlib.patches.Wedge at 0x7de4d69b57b0>,
#   <matplotlib.patches.Wedge at 0x7de4d69b5c30>,
#   <matplotlib.patches.Wedge at 0x7de4d69b60b0>,
#   <matplotlib.patches.Wedge at 0x7de4d69b6530>,
#   <matplotlib.patches.Wedge at 0x7de4d69b69b0>,
#   <matplotlib.patches.Wedge at 0x7de4d69b6e30>,
#   <matplotlib.patches.Wedge at 0x7de4d69b72b0>,
#   <matplotlib.patches.Wedge at 0x7de4d69b7730>,
#   <matplotlib.patches.Wedge at 0x7de4d69b7bb0>,
#   <matplotlib.patches.Wedge at 0x7de4d6774070>,
#   <matplotlib.patches.Wedge at 0x7de4d67744f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6774970>,
#   <matplotlib.patches.Wedge at 0x7de4d6774df0>,
#   <matplotlib.patches.Wedge at 0x7de4d6775270>,
#   <matplotlib.patches.Wedge at 0x7de4d67756f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6775b70>,
#   <matplotlib.patches.Wedge at 0x7de4d6775ff0>,
#   <matplotlib.patches.Wedge at 0x7de4d6776470>,
#   <matplotlib.patches.Wedge at 0x7de4d67768f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6776d70>,
#   <matplotlib.patches.Wedge at 0x7de4d67771f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6777670>,
#   <matplotlib.patches.Wedge at 0x7de4d6777af0>,
#   <matplotlib.patches.Wedge at 0x7de4d6777f70>,
#   <matplotlib.patches.Wedge at 0x7de4d679fb80>,
#   <matplotlib.patches.Wedge at 0x7de4d679f880>,
#   <matplotlib.patches.Wedge at 0x7de4d679eb30>,
#   <matplotlib.patches.Wedge at 0x7de4d679eef0>,
#   <matplotlib.patches.Wedge at 0x7de4d679e980>,
#   <matplotlib.patches.Wedge at 0x7de4d679e3e0>,
#   <matplotlib.patches.Wedge at 0x7de4d679e080>,
#   <matplotlib.patches.Wedge at 0x7de4d679db40>,
#   <matplotlib.patches.Wedge at 0x7de4d679d630>,
#   <matplotlib.patches.Wedge at 0x7de4d679cfd0>,
#   <matplotlib.patches.Wedge at 0x7de4d679e8c0>,
#   <matplotlib.patches.Wedge at 0x7de4d679c9d0>,
#   <matplotlib.patches.Wedge at 0x7de4d679c520>,
#   <matplotlib.patches.Wedge at 0x7de4d679c4c0>,
#   <matplotlib.patches.Wedge at 0x7de4d6784370>,
#   <matplotlib.patches.Wedge at 0x7de4d67847f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6784c70>,
#   <matplotlib.patches.Wedge at 0x7de4d67850f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6785570>,
#   <matplotlib.patches.Wedge at 0x7de4d67859f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6785e70>,
#   <matplotlib.patches.Wedge at 0x7de4d67862f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6786770>,
#   <matplotlib.patches.Wedge at 0x7de4d6786bf0>,
#   <matplotlib.patches.Wedge at 0x7de4d6787070>,
#   <matplotlib.patches.Wedge at 0x7de4d67874f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6787970>,
#   <matplotlib.patches.Wedge at 0x7de4d6787df0>,
#   <matplotlib.patches.Wedge at 0x7de4d65c42b0>,
#   <matplotlib.patches.Wedge at 0x7de4d65c4730>,
#   <matplotlib.patches.Wedge at 0x7de4d65c4bb0>,
#   <matplotlib.patches.Wedge at 0x7de4d65c5030>,
#   <matplotlib.patches.Wedge at 0x7de4d65c54b0>,
#   <matplotlib.patches.Wedge at 0x7de4d65c5930>,
#   <matplotlib.patches.Wedge at 0x7de4d65c5db0>,
#   <matplotlib.patches.Wedge at 0x7de4d65c6230>,
#   <matplotlib.patches.Wedge at 0x7de4d65c66b0>,
#   <matplotlib.patches.Wedge at 0x7de4d65c6b30>,
#   <matplotlib.patches.Wedge at 0x7de4d65c6fb0>,
#   <matplotlib.patches.Wedge at 0x7de4d65c7430>,
#   <matplotlib.patches.Wedge at 0x7de4d65c78b0>,
#   <matplotlib.patches.Wedge at 0x7de4d65c7d30>,
#   <matplotlib.patches.Wedge at 0x7de4d66181f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6618670>,
#   <matplotlib.patches.Wedge at 0x7de4d6618af0>,
#   <matplotlib.patches.Wedge at 0x7de4d6618f70>,
#   <matplotlib.patches.Wedge at 0x7de4d66193f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6619870>,
#   <matplotlib.patches.Wedge at 0x7de4d6619cf0>,
#   <matplotlib.patches.Wedge at 0x7de4d661a170>,
#   <matplotlib.patches.Wedge at 0x7de4d661a5f0>,
#   <matplotlib.patches.Wedge at 0x7de4d661aa70>,
#   <matplotlib.patches.Wedge at 0x7de4d661aef0>,
#   <matplotlib.patches.Wedge at 0x7de4d661b370>,
#   <matplotlib.patches.Wedge at 0x7de4d661b7f0>,
#   <matplotlib.patches.Wedge at 0x7de4d661bc70>,
#   <matplotlib.patches.Wedge at 0x7de4d6638130>,
#   <matplotlib.patches.Wedge at 0x7de4d66385b0>,
#   <matplotlib.patches.Wedge at 0x7de4d6638a30>,
#   <matplotlib.patches.Wedge at 0x7de4d6638eb0>,
#   <matplotlib.patches.Wedge at 0x7de4d6639330>,
#   <matplotlib.patches.Wedge at 0x7de4d66397b0>,
#   <matplotlib.patches.Wedge at 0x7de4d6639c30>,
#   <matplotlib.patches.Wedge at 0x7de4d663a0b0>,
#   <matplotlib.patches.Wedge at 0x7de4d663a530>,
#   <matplotlib.patches.Wedge at 0x7de4d663a9b0>,
#   <matplotlib.patches.Wedge at 0x7de4d663ae30>,
#   <matplotlib.patches.Wedge at 0x7de4d663b2b0>,
#   <matplotlib.patches.Wedge at 0x7de4d663b730>,
#   <matplotlib.patches.Wedge at 0x7de4d663bbb0>,
#   <matplotlib.patches.Wedge at 0x7de4d65e0070>,
#   <matplotlib.patches.Wedge at 0x7de4d65e04f0>,
#   <matplotlib.patches.Wedge at 0x7de4d65e0970>,
#   <matplotlib.patches.Wedge at 0x7de4d65e0df0>,
#   <matplotlib.patches.Wedge at 0x7de4d65e1270>,
#   <matplotlib.patches.Wedge at 0x7de4d65e16f0>,
#   <matplotlib.patches.Wedge at 0x7de4d65e1b70>,
#   <matplotlib.patches.Wedge at 0x7de4d65e1ff0>,
#   <matplotlib.patches.Wedge at 0x7de4d65e2470>,
#   <matplotlib.patches.Wedge at 0x7de4d65e28f0>,
#   <matplotlib.patches.Wedge at 0x7de4d65e2d70>,
#   <matplotlib.patches.Wedge at 0x7de4d65e31f0>,
#   <matplotlib.patches.Wedge at 0x7de4d65e3670>,
#   <matplotlib.patches.Wedge at 0x7de4d65e3af0>,
#   <matplotlib.patches.Wedge at 0x7de4d65e3f70>,
#   <matplotlib.patches.Wedge at 0x7de4d6644430>,
#   <matplotlib.patches.Wedge at 0x7de4d66448b0>,
#   <matplotlib.patches.Wedge at 0x7de4d6644d30>,
#   <matplotlib.patches.Wedge at 0x7de4d66451b0>,
#   <matplotlib.patches.Wedge at 0x7de4d6645630>,
#   <matplotlib.patches.Wedge at 0x7de4d6645ae0>,
#   <matplotlib.patches.Wedge at 0x7de4d6645f90>,
#   <matplotlib.patches.Wedge at 0x7de4d6646410>,
#   <matplotlib.patches.Wedge at 0x7de4d6646890>,
#   <matplotlib.patches.Wedge at 0x7de4d6646d10>,
#   <matplotlib.patches.Wedge at 0x7de4d6647190>,
#   <matplotlib.patches.Wedge at 0x7de4d6647610>,
#   <matplotlib.patches.Wedge at 0x7de4d6647a90>,
#   <matplotlib.patches.Wedge at 0x7de4d6647f10>,
#   <matplotlib.patches.Wedge at 0x7de4d66943d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6694850>,
#   <matplotlib.patches.Wedge at 0x7de4d6694cd0>,
#   <matplotlib.patches.Wedge at 0x7de4d6695150>,
#   <matplotlib.patches.Wedge at 0x7de4d66955d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6695a50>,
#   <matplotlib.patches.Wedge at 0x7de4d6695ed0>,
#   <matplotlib.patches.Wedge at 0x7de4d6696350>,
#   <matplotlib.patches.Wedge at 0x7de4d66967d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6696c50>,
#   <matplotlib.patches.Wedge at 0x7de4d66970d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6697550>,
#   <matplotlib.patches.Wedge at 0x7de4d66979d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6697e50>,
#   <matplotlib.patches.Wedge at 0x7de4d66e4310>,
#   <matplotlib.patches.Wedge at 0x7de4d66e4790>,
#   <matplotlib.patches.Wedge at 0x7de4d66e4c10>,
#   <matplotlib.patches.Wedge at 0x7de4d66e5090>,
#   <matplotlib.patches.Wedge at 0x7de4d66e5510>,
#   <matplotlib.patches.Wedge at 0x7de4d66e5990>,
#   <matplotlib.patches.Wedge at 0x7de4d66e5e10>,
#   <matplotlib.patches.Wedge at 0x7de4d66e6290>,
#   <matplotlib.patches.Wedge at 0x7de4d66e6710>,
#   <matplotlib.patches.Wedge at 0x7de4d66e6b90>,
#   <matplotlib.patches.Wedge at 0x7de4d66e7010>,
#   <matplotlib.patches.Wedge at 0x7de4d66e7490>,
#   <matplotlib.patches.Wedge at 0x7de4d66e7910>,
#   <matplotlib.patches.Wedge at 0x7de4d66e7d90>,
#   <matplotlib.patches.Wedge at 0x7de4d671c250>,
#   <matplotlib.patches.Wedge at 0x7de4d671c6d0>,
#   <matplotlib.patches.Wedge at 0x7de4d671cb50>,
#   <matplotlib.patches.Wedge at 0x7de4d671cfd0>,
#   <matplotlib.patches.Wedge at 0x7de4d671d390>,
#   <matplotlib.patches.Wedge at 0x7de4d671d7b0>,
#   <matplotlib.patches.Wedge at 0x7de4d671dc30>,
#   <matplotlib.patches.Wedge at 0x7de4d671e0b0>,
#   <matplotlib.patches.Wedge at 0x7de4d671e530>,
#   <matplotlib.patches.Wedge at 0x7de4d671e9b0>,
#   <matplotlib.patches.Wedge at 0x7de4d671ee30>,
#   <matplotlib.patches.Wedge at 0x7de4d671f2b0>,
#   <matplotlib.patches.Wedge at 0x7de4d671f730>,
#   <matplotlib.patches.Wedge at 0x7de4d671fbb0>,
#   <matplotlib.patches.Wedge at 0x7de4d6884070>,
#   <matplotlib.patches.Wedge at 0x7de4d68844f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6884970>,
#   <matplotlib.patches.Wedge at 0x7de4d6884df0>,
#   <matplotlib.patches.Wedge at 0x7de4d6885270>,
#   <matplotlib.patches.Wedge at 0x7de4d68856f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6885b70>,
#   <matplotlib.patches.Wedge at 0x7de4d6885ff0>,
#   <matplotlib.patches.Wedge at 0x7de4d6886470>,
#   <matplotlib.patches.Wedge at 0x7de4d68868f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6886d70>,
#   <matplotlib.patches.Wedge at 0x7de4d68871f0>,
#   <matplotlib.patches.Wedge at 0x7de4d6887670>,
#   <matplotlib.patches.Wedge at 0x7de4d6887af0>,
#   <matplotlib.patches.Wedge at 0x7de4d6887f70>,
#   <matplotlib.patches.Wedge at 0x7de4d6894430>,
#   <matplotlib.patches.Wedge at 0x7de4d68948b0>,
#   <matplotlib.patches.Wedge at 0x7de4d6894d30>,
#   <matplotlib.patches.Wedge at 0x7de4d68951b0>,
#   <matplotlib.patches.Wedge at 0x7de4d6895630>,
#   <matplotlib.patches.Wedge at 0x7de4d6895ab0>,
#   <matplotlib.patches.Wedge at 0x7de4d6895f30>,
#   <matplotlib.patches.Wedge at 0x7de4d68963b0>,
#   <matplotlib.patches.Wedge at 0x7de4d6896830>,
#   <matplotlib.patches.Wedge at 0x7de4d6896cb0>,
#   <matplotlib.patches.Wedge at 0x7de4d6897130>,
#   <matplotlib.patches.Wedge at 0x7de4d68975b0>,
#   <matplotlib.patches.Wedge at 0x7de4d6897a30>,
#   <matplotlib.patches.Wedge at 0x7de4d6897eb0>,
#   <matplotlib.patches.Wedge at 0x7de4d68d0370>,
#   <matplotlib.patches.Wedge at 0x7de4d68d07f0>,
#   <matplotlib.patches.Wedge at 0x7de4d68d0c70>,
#   <matplotlib.patches.Wedge at 0x7de4d68d10f0>,
#   <matplotlib.patches.Wedge at 0x7de4d68d1570>,
#   <matplotlib.patches.Wedge at 0x7de4d68d19f0>,
#   <matplotlib.patches.Wedge at 0x7de4d68d1e70>,
#   <matplotlib.patches.Wedge at 0x7de4d68d22f0>,
#   <matplotlib.patches.Wedge at 0x7de4d68d2770>,
#   <matplotlib.patches.Wedge at 0x7de4d68d2bf0>,
#   <matplotlib.patches.Wedge at 0x7de4d68d3130>,
#   <matplotlib.patches.Wedge at 0x7de4d68d3520>,
#   <matplotlib.patches.Wedge at 0x7de4d68d39a0>,
#   <matplotlib.patches.Wedge at 0x7de4d68d3e20>,
#   <matplotlib.patches.Wedge at 0x7de4d69082e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6908760>,
#   <matplotlib.patches.Wedge at 0x7de4d6908be0>,
#   <matplotlib.patches.Wedge at 0x7de4d6909060>,
#   <matplotlib.patches.Wedge at 0x7de4d69094e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6909960>,
#   <matplotlib.patches.Wedge at 0x7de4d6909de0>,
#   <matplotlib.patches.Wedge at 0x7de4d690a260>,
#   <matplotlib.patches.Wedge at 0x7de4d690a6e0>,
#   <matplotlib.patches.Wedge at 0x7de4d690ab60>,
#   <matplotlib.patches.Wedge at 0x7de4d690afe0>,
#   <matplotlib.patches.Wedge at 0x7de4d690b460>,
#   <matplotlib.patches.Wedge at 0x7de4d690b8e0>,
#   <matplotlib.patches.Wedge at 0x7de4d690bd60>,
#   <matplotlib.patches.Wedge at 0x7de4d6444220>,
#   <matplotlib.patches.Wedge at 0x7de4d64446a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6444b20>,
#   <matplotlib.patches.Wedge at 0x7de4d6444fa0>,
#   <matplotlib.patches.Wedge at 0x7de4d6445420>,
#   <matplotlib.patches.Wedge at 0x7de4d64458a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6445d20>,
#   <matplotlib.patches.Wedge at 0x7de4d64461a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6446620>,
#   <matplotlib.patches.Wedge at 0x7de4d6446aa0>,
#   <matplotlib.patches.Wedge at 0x7de4d6446f20>,
#   <matplotlib.patches.Wedge at 0x7de4d64473a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6447820>,
#   <matplotlib.patches.Wedge at 0x7de4d6447ca0>,
#   <matplotlib.patches.Wedge at 0x7de4d648c160>,
#   <matplotlib.patches.Wedge at 0x7de4d648c5e0>,
#   <matplotlib.patches.Wedge at 0x7de4d648ca60>,
#   <matplotlib.patches.Wedge at 0x7de4d648cee0>,
#   <matplotlib.patches.Wedge at 0x7de4d648d360>,
#   <matplotlib.patches.Wedge at 0x7de4d648d7e0>,
#   <matplotlib.patches.Wedge at 0x7de4d648dc60>,
#   <matplotlib.patches.Wedge at 0x7de4d648e0e0>,
#   <matplotlib.patches.Wedge at 0x7de4d648e560>,
#   <matplotlib.patches.Wedge at 0x7de4d648e9e0>,
#   <matplotlib.patches.Wedge at 0x7de4d648ee60>,
#   <matplotlib.patches.Wedge at 0x7de4d648f2e0>,
#   <matplotlib.patches.Wedge at 0x7de4d648f760>,
#   <matplotlib.patches.Wedge at 0x7de4d648fbe0>,
#   <matplotlib.patches.Wedge at 0x7de4d64c40a0>,
#   <matplotlib.patches.Wedge at 0x7de4d64c4520>,
#   <matplotlib.patches.Wedge at 0x7de4d64c49a0>,
#   <matplotlib.patches.Wedge at 0x7de4d64c4e20>,
#   <matplotlib.patches.Wedge at 0x7de4d64c52a0>,
#   <matplotlib.patches.Wedge at 0x7de4d64c5720>,
#   <matplotlib.patches.Wedge at 0x7de4d64c5ba0>,
#   <matplotlib.patches.Wedge at 0x7de4d64c6020>,
#   <matplotlib.patches.Wedge at 0x7de4d64c64a0>,
#   <matplotlib.patches.Wedge at 0x7de4d64c6920>,
#   <matplotlib.patches.Wedge at 0x7de4d64c6da0>,
#   <matplotlib.patches.Wedge at 0x7de4d64c7220>,
#   <matplotlib.patches.Wedge at 0x7de4d64c76a0>,
#   <matplotlib.patches.Wedge at 0x7de4d64c7b20>,
#   <matplotlib.patches.Wedge at 0x7de4d64c7fa0>,
#   <matplotlib.patches.Wedge at 0x7de4d6500460>,
#   <matplotlib.patches.Wedge at 0x7de4d65008e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6500d60>,
#   <matplotlib.patches.Wedge at 0x7de4d65011e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6501660>,
#   <matplotlib.patches.Wedge at 0x7de4d6501ae0>,
#   <matplotlib.patches.Wedge at 0x7de4d6501f60>,
#   <matplotlib.patches.Wedge at 0x7de4d65023e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6502860>,
#   <matplotlib.patches.Wedge at 0x7de4d6502ce0>,
#   <matplotlib.patches.Wedge at 0x7de4d6503160>,
#   <matplotlib.patches.Wedge at 0x7de4d65035e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6503a60>,
#   <matplotlib.patches.Wedge at 0x7de4d6503ee0>,
#   <matplotlib.patches.Wedge at 0x7de4d65343a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6534820>,
#   <matplotlib.patches.Wedge at 0x7de4d6534ca0>,
#   <matplotlib.patches.Wedge at 0x7de4d6535120>,
#   <matplotlib.patches.Wedge at 0x7de4d65355a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6535a20>,
#   <matplotlib.patches.Wedge at 0x7de4d6535ea0>,
#   <matplotlib.patches.Wedge at 0x7de4d6536320>,
#   <matplotlib.patches.Wedge at 0x7de4d65367a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6536c20>,
#   <matplotlib.patches.Wedge at 0x7de4d65370a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6537520>,
#   <matplotlib.patches.Wedge at 0x7de4d65379a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6537e20>,
#   <matplotlib.patches.Wedge at 0x7de4d63742e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6374760>,
#   <matplotlib.patches.Wedge at 0x7de4d6374be0>,
#   <matplotlib.patches.Wedge at 0x7de4d6375060>,
#   <matplotlib.patches.Wedge at 0x7de4d63754e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6375960>,
#   <matplotlib.patches.Wedge at 0x7de4d6375de0>,
#   <matplotlib.patches.Wedge at 0x7de4d6376260>,
#   <matplotlib.patches.Wedge at 0x7de4d63766e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6376b60>,
#   <matplotlib.patches.Wedge at 0x7de4d6376fe0>,
#   <matplotlib.patches.Wedge at 0x7de4d6377460>,
#   <matplotlib.patches.Wedge at 0x7de4d63778e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6377d60>,
#   <matplotlib.patches.Wedge at 0x7de4d63b0220>,
#   <matplotlib.patches.Wedge at 0x7de4d63b06a0>,
#   <matplotlib.patches.Wedge at 0x7de4d63b0b20>,
#   <matplotlib.patches.Wedge at 0x7de4d63b0fa0>,
#   <matplotlib.patches.Wedge at 0x7de4d63b1420>,
#   <matplotlib.patches.Wedge at 0x7de4d63b18a0>,
#   <matplotlib.patches.Wedge at 0x7de4d63b1d20>,
#   <matplotlib.patches.Wedge at 0x7de4d63b21a0>,
#   <matplotlib.patches.Wedge at 0x7de4d63b2620>,
#   <matplotlib.patches.Wedge at 0x7de4d63b2aa0>,
#   <matplotlib.patches.Wedge at 0x7de4d63b2f20>,
#   <matplotlib.patches.Wedge at 0x7de4d63b33a0>,
#   <matplotlib.patches.Wedge at 0x7de4d63b3820>,
#   <matplotlib.patches.Wedge at 0x7de4d63b3ca0>,
#   <matplotlib.patches.Wedge at 0x7de4d63f0160>,
#   <matplotlib.patches.Wedge at 0x7de4d63f05e0>,
#   <matplotlib.patches.Wedge at 0x7de4d63f0a60>,
#   <matplotlib.patches.Wedge at 0x7de4d63f0ee0>,
#   <matplotlib.patches.Wedge at 0x7de4d63f1360>,
#   <matplotlib.patches.Wedge at 0x7de4d63f17e0>,
#   <matplotlib.patches.Wedge at 0x7de4d63f1c60>,
#   <matplotlib.patches.Wedge at 0x7de4d63f20e0>,
#   <matplotlib.patches.Wedge at 0x7de4d63f2560>,
#   <matplotlib.patches.Wedge at 0x7de4d63f29e0>,
#   <matplotlib.patches.Wedge at 0x7de4d63f2e60>,
#   <matplotlib.patches.Wedge at 0x7de4d63f32e0>,
#   <matplotlib.patches.Wedge at 0x7de4d63f3760>,
#   <matplotlib.patches.Wedge at 0x7de4d63f3be0>,
#   <matplotlib.patches.Wedge at 0x7de4d64280a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6428520>,
#   <matplotlib.patches.Wedge at 0x7de4d64289a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6428e20>,
#   <matplotlib.patches.Wedge at 0x7de4d64292a0>,
#   <matplotlib.patches.Wedge at 0x7de4d6429720>,
#   <matplotlib.patches.Wedge at 0x7de4d6429ba0>,
#   <matplotlib.patches.Wedge at 0x7de4d642a020>,
#   <matplotlib.patches.Wedge at 0x7de4d642a4a0>,
#   <matplotlib.patches.Wedge at 0x7de4d642a920>,
#   <matplotlib.patches.Wedge at 0x7de4d642ada0>,
#   <matplotlib.patches.Wedge at 0x7de4d642b220>,
#   <matplotlib.patches.Wedge at 0x7de4d642b6a0>,
#   <matplotlib.patches.Wedge at 0x7de4d642bb20>,
#   <matplotlib.patches.Wedge at 0x7de4d642bfa0>,
#   <matplotlib.patches.Wedge at 0x7de4d6264460>,
#   <matplotlib.patches.Wedge at 0x7de4d62648e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6264d60>,
#   <matplotlib.patches.Wedge at 0x7de4d62651e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6265660>,
#   <matplotlib.patches.Wedge at 0x7de4d6265ae0>,
#   <matplotlib.patches.Wedge at 0x7de4d6266050>,
#   <matplotlib.patches.Wedge at 0x7de4d6266410>,
#   <matplotlib.patches.Wedge at 0x7de4d6266890>,
#   <matplotlib.patches.Wedge at 0x7de4d6266d10>,
#   <matplotlib.patches.Wedge at 0x7de4d6267190>,
#   <matplotlib.patches.Wedge at 0x7de4d6267610>,
#   <matplotlib.patches.Wedge at 0x7de4d6267a90>,
#   <matplotlib.patches.Wedge at 0x7de4d6267f10>,
#   <matplotlib.patches.Wedge at 0x7de4d629c3d0>,
#   <matplotlib.patches.Wedge at 0x7de4d629c850>,
#   <matplotlib.patches.Wedge at 0x7de4d629ccd0>,
#   <matplotlib.patches.Wedge at 0x7de4d629d150>,
#   <matplotlib.patches.Wedge at 0x7de4d629d5d0>,
#   <matplotlib.patches.Wedge at 0x7de4d629da50>,
#   <matplotlib.patches.Wedge at 0x7de4d629ded0>,
#   <matplotlib.patches.Wedge at 0x7de4d629e350>,
#   <matplotlib.patches.Wedge at 0x7de4d629e7d0>,
#   <matplotlib.patches.Wedge at 0x7de4d629ec50>,
#   <matplotlib.patches.Wedge at 0x7de4d629f0d0>,
#   <matplotlib.patches.Wedge at 0x7de4d629f550>,
#   <matplotlib.patches.Wedge at 0x7de4d629f9d0>,
#   <matplotlib.patches.Wedge at 0x7de4d629fe50>,
#   <matplotlib.patches.Wedge at 0x7de4d62dc310>,
#   <matplotlib.patches.Wedge at 0x7de4d62dc790>,
#   <matplotlib.patches.Wedge at 0x7de4d62dcc10>,
#   <matplotlib.patches.Wedge at 0x7de4d62dd090>,
#   <matplotlib.patches.Wedge at 0x7de4d62dd510>,
#   <matplotlib.patches.Wedge at 0x7de4d62dd990>,
#   <matplotlib.patches.Wedge at 0x7de4d62dde10>,
#   <matplotlib.patches.Wedge at 0x7de4d62de290>,
#   <matplotlib.patches.Wedge at 0x7de4d62de710>,
#   <matplotlib.patches.Wedge at 0x7de4d62deb90>,
#   <matplotlib.patches.Wedge at 0x7de4d62df010>,
#   <matplotlib.patches.Wedge at 0x7de4d62df490>,
#   <matplotlib.patches.Wedge at 0x7de4d62df910>,
#   <matplotlib.patches.Wedge at 0x7de4d62dfd90>,
#   <matplotlib.patches.Wedge at 0x7de4d6310250>,
#   <matplotlib.patches.Wedge at 0x7de4d63106d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6310b50>,
#   <matplotlib.patches.Wedge at 0x7de4d6310fd0>,
#   <matplotlib.patches.Wedge at 0x7de4d6311450>,
#   <matplotlib.patches.Wedge at 0x7de4d63118d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6311d50>,
#   <matplotlib.patches.Wedge at 0x7de4d63121d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6312650>,
#   <matplotlib.patches.Wedge at 0x7de4d6312ad0>,
#   <matplotlib.patches.Wedge at 0x7de4d6312f50>,
#   <matplotlib.patches.Wedge at 0x7de4d63133d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6313850>,
#   <matplotlib.patches.Wedge at 0x7de4d6313cd0>,
#   <matplotlib.patches.Wedge at 0x7de4d6154190>,
#   <matplotlib.patches.Wedge at 0x7de4d6154610>,
#   <matplotlib.patches.Wedge at 0x7de4d6154a90>,
#   <matplotlib.patches.Wedge at 0x7de4d6154f10>,
#   <matplotlib.patches.Wedge at 0x7de4d6155390>,
#   <matplotlib.patches.Wedge at 0x7de4d6155810>,
#   <matplotlib.patches.Wedge at 0x7de4d6155c90>,
#   <matplotlib.patches.Wedge at 0x7de4d6156110>,
#   <matplotlib.patches.Wedge at 0x7de4d6156590>,
#   <matplotlib.patches.Wedge at 0x7de4d6156a10>,
#   <matplotlib.patches.Wedge at 0x7de4d6156e90>,
#   <matplotlib.patches.Wedge at 0x7de4d6157310>,
#   <matplotlib.patches.Wedge at 0x7de4d6157790>,
#   <matplotlib.patches.Wedge at 0x7de4d6157c10>,
#   <matplotlib.patches.Wedge at 0x7de4d618c0d0>,
#   <matplotlib.patches.Wedge at 0x7de4d618c550>,
#   <matplotlib.patches.Wedge at 0x7de4d618c9d0>,
#   <matplotlib.patches.Wedge at 0x7de4d618ce50>,
#   <matplotlib.patches.Wedge at 0x7de4d618d2d0>,
#   <matplotlib.patches.Wedge at 0x7de4d618d750>,
#   <matplotlib.patches.Wedge at 0x7de4d618dbd0>,
#   <matplotlib.patches.Wedge at 0x7de4d618e050>,
#   <matplotlib.patches.Wedge at 0x7de4d618e4d0>,
#   <matplotlib.patches.Wedge at 0x7de4d618e950>,
#   <matplotlib.patches.Wedge at 0x7de4d618edd0>,
#   <matplotlib.patches.Wedge at 0x7de4d618f250>,
#   <matplotlib.patches.Wedge at 0x7de4d618f6d0>,
#   <matplotlib.patches.Wedge at 0x7de4d618fb50>,
#   <matplotlib.patches.Wedge at 0x7de4d618ffd0>,
#   <matplotlib.patches.Wedge at 0x7de4d61cc490>,
#   <matplotlib.patches.Wedge at 0x7de4d61cc910>,
#   <matplotlib.patches.Wedge at 0x7de4d61ccd90>,
#   <matplotlib.patches.Wedge at 0x7de4d61cd210>,
#   <matplotlib.patches.Wedge at 0x7de4d61cd690>,
#   <matplotlib.patches.Wedge at 0x7de4d61cdb10>,
#   <matplotlib.patches.Wedge at 0x7de4d61cdf90>,
#   <matplotlib.patches.Wedge at 0x7de4d61ce410>,
#   <matplotlib.patches.Wedge at 0x7de4d61ce890>,
#   <matplotlib.patches.Wedge at 0x7de4d61ced10>,
#   <matplotlib.patches.Wedge at 0x7de4d61cf190>,
#   <matplotlib.patches.Wedge at 0x7de4d61cf610>,
#   <matplotlib.patches.Wedge at 0x7de4d61cfa90>,
#   <matplotlib.patches.Wedge at 0x7de4d61cff10>,
#   <matplotlib.patches.Wedge at 0x7de4d62043d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6204850>,
#   <matplotlib.patches.Wedge at 0x7de4d6204cd0>,
#   <matplotlib.patches.Wedge at 0x7de4d6205150>,
#   <matplotlib.patches.Wedge at 0x7de4d62055d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6205a50>,
#   <matplotlib.patches.Wedge at 0x7de4d6205ed0>,
#   <matplotlib.patches.Wedge at 0x7de4d6206350>,
#   <matplotlib.patches.Wedge at 0x7de4d62067d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6206c50>,
#   <matplotlib.patches.Wedge at 0x7de4d62070d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6207550>,
#   <matplotlib.patches.Wedge at 0x7de4d62079d0>,
#   <matplotlib.patches.Wedge at 0x7de4d6207e50>,
#   <matplotlib.patches.Wedge at 0x7de4d623c310>,
#   <matplotlib.patches.Wedge at 0x7de4d623c790>,
#   <matplotlib.patches.Wedge at 0x7de4d623cc10>,
#   <matplotlib.patches.Wedge at 0x7de4d623d090>,
#   <matplotlib.patches.Wedge at 0x7de4d623d510>,
#   <matplotlib.patches.Wedge at 0x7de4d623d990>,
#   <matplotlib.patches.Wedge at 0x7de4d623de10>,
#   <matplotlib.patches.Wedge at 0x7de4d623e290>,
#   <matplotlib.patches.Wedge at 0x7de4d623e710>,
#   <matplotlib.patches.Wedge at 0x7de4d623eb90>,
#   <matplotlib.patches.Wedge at 0x7de4d623f010>,
#   <matplotlib.patches.Wedge at 0x7de4d623f490>,
#   <matplotlib.patches.Wedge at 0x7de4d623f910>,
#   <matplotlib.patches.Wedge at 0x7de4d623fd90>,
#   <matplotlib.patches.Wedge at 0x7de4d607c250>,
#   <matplotlib.patches.Wedge at 0x7de4d607c6d0>,
#   <matplotlib.patches.Wedge at 0x7de4d607cb50>,
#   <matplotlib.patches.Wedge at 0x7de4d607cfd0>,
#   <matplotlib.patches.Wedge at 0x7de4d607d450>,
#   <matplotlib.patches.Wedge at 0x7de4d607d8d0>,
#   <matplotlib.patches.Wedge at 0x7de4d607dd50>,
#   <matplotlib.patches.Wedge at 0x7de4d607e1d0>,
#   <matplotlib.patches.Wedge at 0x7de4d607e650>,
#   <matplotlib.patches.Wedge at 0x7de4d607ead0>,
#   <matplotlib.patches.Wedge at 0x7de4d607ef50>,
#   <matplotlib.patches.Wedge at 0x7de4d607f3d0>,
#   <matplotlib.patches.Wedge at 0x7de4d607f850>,
#   <matplotlib.patches.Wedge at 0x7de4d607fcd0>,
#   <matplotlib.patches.Wedge at 0x7de4d60bc190>,
#   <matplotlib.patches.Wedge at 0x7de4d60bc610>,
#   <matplotlib.patches.Wedge at 0x7de4d60bca90>,
#   <matplotlib.patches.Wedge at 0x7de4d60bcf10>,
#   <matplotlib.patches.Wedge at 0x7de4d60bd390>,
#   <matplotlib.patches.Wedge at 0x7de4d60bd810>,
#   <matplotlib.patches.Wedge at 0x7de4d60bdc90>,
#   <matplotlib.patches.Wedge at 0x7de4d60be110>,
#   <matplotlib.patches.Wedge at 0x7de4d60be590>,
#   <matplotlib.patches.Wedge at 0x7de4d60bea10>,
#   <matplotlib.patches.Wedge at 0x7de4d60bee90>,
#   <matplotlib.patches.Wedge at 0x7de4d60bf310>,
#   <matplotlib.patches.Wedge at 0x7de4d60bf790>,
#   <matplotlib.patches.Wedge at 0x7de4d60bfc10>,
#   <matplotlib.patches.Wedge at 0x7de4d60f00d0>,
#   <matplotlib.patches.Wedge at 0x7de4d60f0550>,
#   <matplotlib.patches.Wedge at 0x7de4d60f09d0>,
#   <matplotlib.patches.Wedge at 0x7de4d60f0e50>,
#   <matplotlib.patches.Wedge at 0x7de4d60f12d0>,
#   <matplotlib.patches.Wedge at 0x7de4d60f1750>,
#   <matplotlib.patches.Wedge at 0x7de4d60f1bd0>,
#   <matplotlib.patches.Wedge at 0x7de4d60f2050>,
#   <matplotlib.patches.Wedge at 0x7de4d60f24d0>,
#   <matplotlib.patches.Wedge at 0x7de4d60f2950>,
#   <matplotlib.patches.Wedge at 0x7de4d60f2dd0>,
#   <matplotlib.patches.Wedge at 0x7de4d60f3250>,
#   <matplotlib.patches.Wedge at 0x7de4d60f36d0>,
#   <matplotlib.patches.Wedge at 0x7de4d60f3b50>,
#   <matplotlib.patches.Wedge at 0x7de4d60f3f70>,
#   <matplotlib.patches.Wedge at 0x7de4d6134460>,
#   <matplotlib.patches.Wedge at 0x7de4d61348e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6134d60>,
#   <matplotlib.patches.Wedge at 0x7de4d61351e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6135660>,
#   <matplotlib.patches.Wedge at 0x7de4d6135ae0>,
#   <matplotlib.patches.Wedge at 0x7de4d6135f60>,
#   <matplotlib.patches.Wedge at 0x7de4d61363e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6136860>,
#   <matplotlib.patches.Wedge at 0x7de4d6136ce0>,
#   <matplotlib.patches.Wedge at 0x7de4d6137160>,
#   <matplotlib.patches.Wedge at 0x7de4d61375e0>,
#   <matplotlib.patches.Wedge at 0x7de4d6137a60>,
#   <matplotlib.patches.Wedge at 0x7de4d6137ee0>,
#   <matplotlib.patches.Wedge at 0x7de4d5f683a0>,
#   <matplotlib.patches.Wedge at 0x7de4d5f68820>,
#   <matplotlib.patches.Wedge at 0x7de4d5f68cd0>,
#   <matplotlib.patches.Wedge at 0x7de4d5f69150>,
#   <matplotlib.patches.Wedge at 0x7de4d5f695d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5f69a50>,
#   <matplotlib.patches.Wedge at 0x7de4d5f69ed0>,
#   <matplotlib.patches.Wedge at 0x7de4d5f6a350>,
#   <matplotlib.patches.Wedge at 0x7de4d5f6a7d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5f6ac50>,
#   <matplotlib.patches.Wedge at 0x7de4d5f6b0d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5f6b550>,
#   <matplotlib.patches.Wedge at 0x7de4d5f6b9d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5f6be50>,
#   <matplotlib.patches.Wedge at 0x7de4d5fa4310>,
#   <matplotlib.patches.Wedge at 0x7de4d5fa4790>,
#   <matplotlib.patches.Wedge at 0x7de4d5fa4c10>,
#   <matplotlib.patches.Wedge at 0x7de4d5fa5090>,
#   <matplotlib.patches.Wedge at 0x7de4d5fa5510>,
#   <matplotlib.patches.Wedge at 0x7de4d5fa5990>,
#   <matplotlib.patches.Wedge at 0x7de4d5fa5e10>,
#   <matplotlib.patches.Wedge at 0x7de4d5fa6290>,
#   <matplotlib.patches.Wedge at 0x7de4d5fa6710>,
#   <matplotlib.patches.Wedge at 0x7de4d5fa6b90>,
#   <matplotlib.patches.Wedge at 0x7de4d5fa7010>,
#   <matplotlib.patches.Wedge at 0x7de4d5fa7490>,
#   <matplotlib.patches.Wedge at 0x7de4d5fa7910>,
#   <matplotlib.patches.Wedge at 0x7de4d5fa7d90>,
#   <matplotlib.patches.Wedge at 0x7de4d5fe0250>,
#   <matplotlib.patches.Wedge at 0x7de4d5fe06d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5fe0b50>,
#   <matplotlib.patches.Wedge at 0x7de4d5fe0fd0>,
#   <matplotlib.patches.Wedge at 0x7de4d5fe1450>,
#   <matplotlib.patches.Wedge at 0x7de4d5fe18d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5fe1d50>,
#   <matplotlib.patches.Wedge at 0x7de4d5fe21d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5fe2650>,
#   <matplotlib.patches.Wedge at 0x7de4d5fe2ad0>,
#   <matplotlib.patches.Wedge at 0x7de4d5fe2f50>,
#   <matplotlib.patches.Wedge at 0x7de4d5fe33d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5fe3850>,
#   <matplotlib.patches.Wedge at 0x7de4d5fe3cd0>,
#   <matplotlib.patches.Wedge at 0x7de4d601c190>,
#   <matplotlib.patches.Wedge at 0x7de4d601c610>,
#   <matplotlib.patches.Wedge at 0x7de4d601ca90>,
#   <matplotlib.patches.Wedge at 0x7de4d601cf10>,
#   <matplotlib.patches.Wedge at 0x7de4d601d390>,
#   <matplotlib.patches.Wedge at 0x7de4d601d810>,
#   <matplotlib.patches.Wedge at 0x7de4d601dc90>,
#   <matplotlib.patches.Wedge at 0x7de4d601e110>,
#   <matplotlib.patches.Wedge at 0x7de4d601e590>,
#   <matplotlib.patches.Wedge at 0x7de4d601ea10>,
#   <matplotlib.patches.Wedge at 0x7de4d601ee90>,
#   <matplotlib.patches.Wedge at 0x7de4d601f310>,
#   <matplotlib.patches.Wedge at 0x7de4d601f790>,
#   <matplotlib.patches.Wedge at 0x7de4d601fc10>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5c0d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5c550>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5c9d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5ce50>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5d2d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5d750>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5dbd0>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5e050>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5e4d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5e950>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5edd0>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5f250>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5f6d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5fb50>,
#   <matplotlib.patches.Wedge at 0x7de4d5e5ffd0>,
#   <matplotlib.patches.Wedge at 0x7de4d5e98490>,
#   <matplotlib.patches.Wedge at 0x7de4d5e98910>,
#   <matplotlib.patches.Wedge at 0x7de4d5e98d90>,
#   <matplotlib.patches.Wedge at 0x7de4d5e99210>,
#   <matplotlib.patches.Wedge at 0x7de4d5e99690>,
#   <matplotlib.patches.Wedge at 0x7de4d5e99b10>,
#   <matplotlib.patches.Wedge at 0x7de4d5e99f90>,
#   <matplotlib.patches.Wedge at 0x7de4d5e9a410>,
#   <matplotlib.patches.Wedge at 0x7de4d5e9a890>,
#   <matplotlib.patches.Wedge at 0x7de4d5e9ad10>,
#   <matplotlib.patches.Wedge at 0x7de4d5e9b190>,
#   <matplotlib.patches.Wedge at 0x7de4d5e9b610>,
#   <matplotlib.patches.Wedge at 0x7de4d5e9ba90>,
#   <matplotlib.patches.Wedge at 0x7de4d5e9bf10>,
#   <matplotlib.patches.Wedge at 0x7de4d5ecc3d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5ecc850>,
#   <matplotlib.patches.Wedge at 0x7de4d5ecccd0>,
#   <matplotlib.patches.Wedge at 0x7de4d5ecd150>,
#   <matplotlib.patches.Wedge at 0x7de4d5ecd5d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5ecda50>,
#   <matplotlib.patches.Wedge at 0x7de4d5ecded0>,
#   <matplotlib.patches.Wedge at 0x7de4d5ece350>,
#   <matplotlib.patches.Wedge at 0x7de4d5ece7d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5ecec50>,
#   <matplotlib.patches.Wedge at 0x7de4d5ecf0d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5ecf550>,
#   <matplotlib.patches.Wedge at 0x7de4d5ecf9d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5ecfe50>,
#   <matplotlib.patches.Wedge at 0x7de4d5f08310>,
#   <matplotlib.patches.Wedge at 0x7de4d5f08790>,
#   <matplotlib.patches.Wedge at 0x7de4d5f08c10>,
#   <matplotlib.patches.Wedge at 0x7de4d5f09090>,
#   <matplotlib.patches.Wedge at 0x7de4d5f09510>,
#   <matplotlib.patches.Wedge at 0x7de4d5f09990>,
#   <matplotlib.patches.Wedge at 0x7de4d5f09e10>,
#   <matplotlib.patches.Wedge at 0x7de4d5f0a290>,
#   <matplotlib.patches.Wedge at 0x7de4d5f0a710>,
#   <matplotlib.patches.Wedge at 0x7de4d5f0ab90>,
#   <matplotlib.patches.Wedge at 0x7de4d5f0b010>,
#   <matplotlib.patches.Wedge at 0x7de4d5f0b490>,
#   <matplotlib.patches.Wedge at 0x7de4d5f0b910>,
#   <matplotlib.patches.Wedge at 0x7de4d5f0bd90>,
#   <matplotlib.patches.Wedge at 0x7de4d5d44250>,
#   <matplotlib.patches.Wedge at 0x7de4d5d446d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5d44b50>,
#   <matplotlib.patches.Wedge at 0x7de4d5d44fd0>,
#   <matplotlib.patches.Wedge at 0x7de4d5d45450>,
#   <matplotlib.patches.Wedge at 0x7de4d5d458d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5d45d50>,
#   <matplotlib.patches.Wedge at 0x7de4d5d461d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5d46650>,
#   <matplotlib.patches.Wedge at 0x7de4d5d46ad0>,
#   <matplotlib.patches.Wedge at 0x7de4d5d46f50>,
#   <matplotlib.patches.Wedge at 0x7de4d5d473d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5d47850>,
#   <matplotlib.patches.Wedge at 0x7de4d5d47cd0>,
#   <matplotlib.patches.Wedge at 0x7de4d5d84190>,
#   <matplotlib.patches.Wedge at 0x7de4d5d84610>,
#   <matplotlib.patches.Wedge at 0x7de4d5d84a90>,
#   <matplotlib.patches.Wedge at 0x7de4d5d84f10>,
#   <matplotlib.patches.Wedge at 0x7de4d5d85390>,
#   <matplotlib.patches.Wedge at 0x7de4d5d85810>,
#   <matplotlib.patches.Wedge at 0x7de4d5d85c90>,
#   <matplotlib.patches.Wedge at 0x7de4d5d86110>,
#   <matplotlib.patches.Wedge at 0x7de4d5d86590>,
#   <matplotlib.patches.Wedge at 0x7de4d5d86a10>,
#   <matplotlib.patches.Wedge at 0x7de4d5d86e90>,
#   <matplotlib.patches.Wedge at 0x7de4d5d87310>,
#   <matplotlib.patches.Wedge at 0x7de4d5d87790>,
#   <matplotlib.patches.Wedge at 0x7de4d5d87c10>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbc0d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbc550>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbc9d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbce50>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbd2d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbd750>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbdbd0>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbe050>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbe4d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbe950>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbedd0>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbf250>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbf6d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbfb50>,
#   <matplotlib.patches.Wedge at 0x7de4d5dbffd0>,
#   <matplotlib.patches.Wedge at 0x7de4d5df8490>,
#   <matplotlib.patches.Wedge at 0x7de4d5df8910>,
#   <matplotlib.patches.Wedge at 0x7de4d5df8d90>,
#   <matplotlib.patches.Wedge at 0x7de4d5df9210>,
#   <matplotlib.patches.Wedge at 0x7de4d5df9690>,
#   <matplotlib.patches.Wedge at 0x7de4d5df9c00>,
#   <matplotlib.patches.Wedge at 0x7de4d5df9fc0>,
#   <matplotlib.patches.Wedge at 0x7de4d5dfa440>,
#   <matplotlib.patches.Wedge at 0x7de4d5dfa8c0>,
#   <matplotlib.patches.Wedge at 0x7de4d5dfad40>,
#   <matplotlib.patches.Wedge at 0x7de4d5dfb1c0>,
#   <matplotlib.patches.Wedge at 0x7de4d5dfb640>,
#   <matplotlib.patches.Wedge at 0x7de4d5dfbac0>,
#   <matplotlib.patches.Wedge at 0x7de4d5dfbf40>,
#   <matplotlib.patches.Wedge at 0x7de4d5e34400>,
#   <matplotlib.patches.Wedge at 0x7de4d5e34880>,
#   <matplotlib.patches.Wedge at 0x7de4d5e34d00>,
#   <matplotlib.patches.Wedge at 0x7de4d5e35180>,
#   <matplotlib.patches.Wedge at 0x7de4d5e35600>,
#   <matplotlib.patches.Wedge at 0x7de4d5e35a80>,
#   <matplotlib.patches.Wedge at 0x7de4d5e35f00>,
#   <matplotlib.patches.Wedge at 0x7de4d5e36380>,
#   <matplotlib.patches.Wedge at 0x7de4d5e36800>,
#   <matplotlib.patches.Wedge at 0x7de4d5e36c80>,
#   <matplotlib.patches.Wedge at 0x7de4d5e37100>,
#   <matplotlib.patches.Wedge at 0x7de4d5e37580>,
#   <matplotlib.patches.Wedge at 0x7de4d5e37a00>,
#   <matplotlib.patches.Wedge at 0x7de4d5e37e80>,
#   <matplotlib.patches.Wedge at 0x7de4d5c74340>,
#   <matplotlib.patches.Wedge at 0x7de4d5c747c0>,
#   <matplotlib.patches.Wedge at 0x7de4d5c74c40>,
#   <matplotlib.patches.Wedge at 0x7de4d5c750c0>,
#   <matplotlib.patches.Wedge at 0x7de4d5c75540>,
#   <matplotlib.patches.Wedge at 0x7de4d5c759c0>,
#   <matplotlib.patches.Wedge at 0x7de4d5c75e40>,
#   <matplotlib.patches.Wedge at 0x7de4d5c762c0>,
#   <matplotlib.patches.Wedge at 0x7de4d5c76740>,
#   <matplotlib.patches.Wedge at 0x7de4d5c76bc0>,
#   <matplotlib.patches.Wedge at 0x7de4d5c77040>,
#   <matplotlib.patches.Wedge at 0x7de4d5c774c0>,
#   <matplotlib.patches.Wedge at 0x7de4d5c77940>,
#   <matplotlib.patches.Wedge at 0x7de4d5c77dc0>,
#   <matplotlib.patches.Wedge at 0x7de4d5cac280>,
#   <matplotlib.patches.Wedge at 0x7de4d5cac700>,
#   <matplotlib.patches.Wedge at 0x7de4d5cacb80>,
#   <matplotlib.patches.Wedge at 0x7de4d5cad000>,
#   <matplotlib.patches.Wedge at 0x7de4d5cad480>,
#   <matplotlib.patches.Wedge at 0x7de4d5cad900>,
#   <matplotlib.patches.Wedge at 0x7de4d5cadd80>,
#   <matplotlib.patches.Wedge at 0x7de4d5cae200>,
#   <matplotlib.patches.Wedge at 0x7de4d5cae680>,
#   <matplotlib.patches.Wedge at 0x7de4d5caeb00>,
#   <matplotlib.patches.Wedge at 0x7de4d5caef80>,
#   <matplotlib.patches.Wedge at 0x7de4d5caf400>,
#   <matplotlib.patches.Wedge at 0x7de4d5caf880>,
#   <matplotlib.patches.Wedge at 0x7de4d5cafd00>,
#   <matplotlib.patches.Wedge at 0x7de4d5ce81c0>,
#   <matplotlib.patches.Wedge at 0x7de4d5ce84c0>,
#   <matplotlib.patches.Wedge at 0x7de4d5ce8a90>,
#   <matplotlib.patches.Wedge at 0x7de4d5ce8f10>,
#   <matplotlib.patches.Wedge at 0x7de4d5ce9390>,
#   <matplotlib.patches.Wedge at 0x7de4d5ce9810>,
#   <matplotlib.patches.Wedge at 0x7de4d5ce9c90>,
#   <matplotlib.patches.Wedge at 0x7de4d5cea110>,
#   <matplotlib.patches.Wedge at 0x7de4d5cea590>,
#   <matplotlib.patches.Wedge at 0x7de4d5ceaa10>,
#   <matplotlib.patches.Wedge at 0x7de4d5ceae90>,
#   <matplotlib.patches.Wedge at 0x7de4d5ceb310>,
#   <matplotlib.patches.Wedge at 0x7de4d5ceb790>,
#   <matplotlib.patches.Wedge at 0x7de4d5cebc10>,
#   <matplotlib.patches.Wedge at 0x7de4d5d240d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5d24550>,
#   <matplotlib.patches.Wedge at 0x7de4d5d249d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5d24e50>,
#   <matplotlib.patches.Wedge at 0x7de4d5d252d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5d25750>,
#   <matplotlib.patches.Wedge at 0x7de4d5d25bd0>,
#   <matplotlib.patches.Wedge at 0x7de4d5d26050>,
#   <matplotlib.patches.Wedge at 0x7de4d5d264d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5d26950>,
#   <matplotlib.patches.Wedge at 0x7de4d5d26dd0>,
#   <matplotlib.patches.Wedge at 0x7de4d5d27250>,
#   <matplotlib.patches.Wedge at 0x7de4d5d276d0>,
#   <matplotlib.patches.Wedge at 0x7de4d5d27b50>,
#   <matplotlib.patches.Wedge at 0x7de4d5d27fd0>,
#   <matplotlib.patches.Wedge at 0x7de4d5b64490>,
#   <matplotlib.patches.Wedge at 0x7de4d5b64910>,
#   <matplotlib.patches.Wedge at 0x7de4d5b64dc0>,
#   <matplotlib.patches.Wedge at 0x7de4d5b65240>,
#   <matplotlib.patches.Wedge at 0x7de4d5b656c0>,
#   <matplotlib.patches.Wedge at 0x7de4d5b65b40>,
#   <matplotlib.patches.Wedge at 0x7de4d5b65fc0>,
#   <matplotlib.patches.Wedge at 0x7de4d5b66440>,
#   <matplotlib.patches.Wedge at 0x7de4d5b668c0>,
#   <matplotlib.patches.Wedge at 0x7de4d5b66d40>,
#   <matplotlib.patches.Wedge at 0x7de4d5b671c0>,
#   <matplotlib.patches.Wedge at 0x7de4d5b67640>,
#   <matplotlib.patches.Wedge at 0x7de4d5b67ac0>,
#   <matplotlib.patches.Wedge at 0x7de4d5b67f40>,
#   <matplotlib.patches.Wedge at 0x7de4d5b98400>,
#   <matplotlib.patches.Wedge at 0x7de4d5b98880>,
#   <matplotlib.patches.Wedge at 0x7de4d5b98d00>,
#   <matplotlib.patches.Wedge at 0x7de4d5b991b0>,
#   <matplotlib.patches.Wedge at 0x7de4d5b99630>,
#   <matplotlib.patches.Wedge at 0x7de4d5b99ab0>,
#   <matplotlib.patches.Wedge at 0x7de4d5b99f30>,
#   <matplotlib.patches.Wedge at 0x7de4d5b9a3b0>,
#   <matplotlib.patches.Wedge at 0x7de4d5b9a830>,
#   <matplotlib.patches.Wedge at 0x7de4d5b9acb0>,
#   <matplotlib.patches.Wedge at 0x7de4d5b9b130>,
#   <matplotlib.patches.Wedge at 0x7de4d5b9b5b0>,
#   <matplotlib.patches.Wedge at 0x7de4d5b9ba30>,
#   <matplotlib.patches.Wedge at 0x7de4d5b9beb0>,
#   <matplotlib.patches.Wedge at 0x7de4d5bd4370>,
#   <matplotlib.patches.Wedge at 0x7de4d5bd47f0>,
#   <matplotlib.patches.Wedge at 0x7de4d5bd4c70>,
#   <matplotlib.patches.Wedge at 0x7de4d5bd50f0>,
#   <matplotlib.patches.Wedge at 0x7de4d5bd5570>,
#   <matplotlib.patches.Wedge at 0x7de4d5bd59f0>,
#   <matplotlib.patches.Wedge at 0x7de4d5bd5e70>,
#   <matplotlib.patches.Wedge at 0x7de4d5bd62f0>,
#   <matplotlib.patches.Wedge at 0x7de4d5bd6770>,
#   <matplotlib.patches.Wedge at 0x7de4d5bd6bf0>,
#   <matplotlib.patches.Wedge at 0x7de4d5bd7070>,
#   <matplotlib.patches.Wedge at 0x7de4d5bd74f0>,
#   <matplotlib.patches.Wedge at 0x7de4d5bd7970>,
#   <matplotlib.patches.Wedge at 0x7de4d5bd7df0>,
#   <matplotlib.patches.Wedge at 0x7de4d5c102b0>,
#   <matplotlib.patches.Wedge at 0x7de4d5c10730>,
#   <matplotlib.patches.Wedge at 0x7de4d5c10bb0>,
#   <matplotlib.patches.Wedge at 0x7de4d5c11030>,
#   <matplotlib.patches.Wedge at 0x7de4d5c114b0>,
#   <matplotlib.patches.Wedge at 0x7de4d5c11930>,
#   <matplotlib.patches.Wedge at 0x7de4d5c11db0>,
#   <matplotlib.patches.Wedge at 0x7de4d5c12230>,
#   <matplotlib.patches.Wedge at 0x7de4d5c126b0>,
#   <matplotlib.patches.Wedge at 0x7de4d5c12b30>,
#   <matplotlib.patches.Wedge at 0x7de4d5c12fb0>,
#   <matplotlib.patches.Wedge at 0x7de4d5c13430>,
#   <matplotlib.patches.Wedge at 0x7de4d5c138b0>,
#   <matplotlib.patches.Wedge at 0x7de4d5c13d30>,
#   <matplotlib.patches.Wedge at 0x7de4d5a501f0>,
#   <matplotlib.patches.Wedge at 0x7de4d5a50670>,
#   <matplotlib.patches.Wedge at 0x7de4d5a50af0>,
#   <matplotlib.patches.Wedge at 0x7de4d5a50f70>,
#   <matplotlib.patches.Wedge at 0x7de4d5a513f0>,
#   <matplotlib.patches.Wedge at 0x7de4d5a51870>,
#   <matplotlib.patches.Wedge at 0x7de4d5a51cf0>,
#   <matplotlib.patches.Wedge at 0x7de4d5a52170>,
#   <matplotlib.patches.Wedge at 0x7de4d5a525f0>,
#   <matplotlib.patches.Wedge at 0x7de4d5a52a70>,
#   <matplotlib.patches.Wedge at 0x7de4d5a52ef0>,
#   <matplotlib.patches.Wedge at 0x7de4d5a53370>,
#   <matplotlib.patches.Wedge at 0x7de4d5a537f0>,
#   <matplotlib.patches.Wedge at 0x7de4d5a53c70>,
#   <matplotlib.patches.Wedge at 0x7de4d5a84130>,
#   <matplotlib.patches.Wedge at 0x7de4d5a845b0>,
#   <matplotlib.patches.Wedge at 0x7de4d5a84a30>,
#   <matplotlib.patches.Wedge at 0x7de4d5a84eb0>,
#   <matplotlib.patches.Wedge at 0x7de4d5a85330>,
#   <matplotlib.patches.Wedge at 0x7de4d5a857b0>,
#   <matplotlib.patches.Wedge at 0x7de4d5a85c30>,
#   <matplotlib.patches.Wedge at 0x7de4d5a860b0>,
#   <matplotlib.patches.Wedge at 0x7de4d5a86530>,
#   <matplotlib.patches.Wedge at 0x7de4d5a869b0>,
#   <matplotlib.patches.Wedge at 0x7de4d5a86e30>,
#   <matplotlib.patches.Wedge at 0x7de4d5a872b0>,
#   <matplotlib.patches.Wedge at 0x7de4d5a87730>,
#   <matplotlib.patches.Wedge at 0x7de4d5a87bb0>,
#   <matplotlib.patches.Wedge at 0x7de4d5abc070>,
#   <matplotlib.patches.Wedge at 0x7de4d5abc4f0>,
#   <matplotlib.patches.Wedge at 0x7de4d5abc970>,
#   <matplotlib.patches.Wedge at 0x7de4d5abcdf0>,
#   <matplotlib.patches.Wedge at 0x7de4d5abd270>,
#   <matplotlib.patches.Wedge at 0x7de4d5abd6f0>,
#   <matplotlib.patches.Wedge at 0x7de4d5abdb70>,
#   <matplotlib.patches.Wedge at 0x7de4d5abdff0>,
#   <matplotlib.patches.Wedge at 0x7de4d5abe470>,
#   <matplotlib.patches.Wedge at 0x7de4d5abe8f0>,
#   <matplotlib.patches.Wedge at 0x7de4d5abed70>,
# ...
#   Text(0.6002274883506398, 0.9218063583140892, ''),
#   Text(0.5996494470255777, 0.9221824877332682, ''),
#   Text(0.5990796757898295, 0.9225527313143422, ''),
#   Text(0.5985522211645455, 0.9228950311595513, ''),
#   Text(0.5976329622136289, 0.9234905751959591, ''),
#   Text(0.5965256609953961, 0.9242062192898326, ''),
#   Text(0.5955027761871468, 0.9248656354051659, ''),
#   Text(0.5943596934181644, 0.9256006454404976, ''),
#   Text(0.5931388357979392, 0.9263834635118792, ''),
#   Text(0.5920708079469565, 0.9270664260866306, ''),
#   Text(0.5910533147460914, 0.9277154623739211, ''),
#   Text(0.5899837532269187, 0.9283960205258737, ''),
#   Text(0.5889990645095053, 0.9290210449752621, ''),
#   Text(0.5881251342830878, 0.9295745405423387, ''),
#   Text(0.5871735016007629, 0.9301759398188598, ''),
#   Text(0.5862813237256503, 0.9307385290458859, ''),
#   Text(0.5854658824413217, 0.9312516848291899, ''),
#   Text(0.584521126183789, 0.9318449726455764, ''),
#   Text(0.5836531387142332, 0.9323888747025161, ''),
#   Text(0.5828448540885015, 0.9328943541808761, ''),
#   Text(0.5819500716261157, 0.933452791593854, ''),
#   Text(0.5811666980178471, 0.9339407203431236, ''),
#   Text(0.5804690652909613, 0.9343744775197137, ''),
#   Text(0.5797883462109849, 0.9347970226728, ''),
#   Text(0.5792452738070749, 0.935133633643966, ''),
#   Text(0.5788572452896751, 0.9353738768939664, ''),
#   Text(0.5784949954443541, 0.9355979586584383, ''),
#   Text(0.5775199403052949, 0.936200148766154, ''),
#   Text(0.5759741014278006, 0.9371519804623143, ''),
#   Text(0.5745045338884013, 0.9380535915083268, ''),
#   Text(0.5731720601089082, 0.938868355793564, ''),
#   Text(0.5719250651189531, 0.9396285009984964, ''),
#   Text(0.5707724311093382, 0.9403291082836562, ''),
#   Text(0.5695929103694379, 0.9410440565971785, ''),
#   Text(0.5682475118095218, 0.9418570832787146, ''),
#   Text(0.5668574960727144, 0.9426943190378166, ''),
#   Text(0.5654662467849118, 0.9435295033791924, ''),
#   Text(0.5640389392902871, 0.9443834364093263, ''),
#   Text(0.5626103422402859, 0.9452352103070794, ''),
#   Text(0.5612502390430676, 0.9460434287991749, ''),
#   Text(0.5598453253658063, 0.946875499559501, ''),
#   Text(0.5584217027350771, 0.9477157811888844, ''),
#   Text(0.5570667812705294, 0.9485128366052261, ''),
#   Text(0.5556844646053875, 0.949323325214452, ''),
#   Text(0.5542571680138723, 0.9501573510241565, ''),
#   Text(0.5529338314767125, 0.9509280614265638, ''),
#   Text(0.5515567756422405, 0.9517274416780969, ''),
#   Text(0.5503190716299567, 0.9524436568114373, ''),
#   Text(0.5491155889785329, 0.9531380120112507, ''),
#   Text(0.5476649762348815, 0.9539722605011358, ''),
#   Text(0.5462218991050012, 0.9547992652584762, ''),
#   Text(0.5447511410085059, 0.9556391548957855, ''),
#   Text(0.5430938922385473, 0.9565819485089532, ''),
#   Text(0.5414968077833253, 0.9574869227098972, ''),
#   Text(0.5400749293731105, 0.9582896590606776, ''),
#   Text(0.5384219372523603, 0.9592193792274089, ''),
#   Text(0.5368204579575169, 0.9601165532987556, ''),
#   Text(0.5355009910802035, 0.960853104564959, ''),
#   Text(0.5340563900126762, 0.9616567850780383, ''),
#   Text(0.5324331001151587, 0.9625564886809301, ''),
#   Text(0.5307105804665541, 0.9635072806060437, ''),
#   Text(0.5288974399332997, 0.9645037573965183, ''),
#   Text(0.5270646249940456, 0.9655065411895905, ''),
#   Text(0.5252477306229145, 0.9664961569895032, ''),
#   Text(0.5235806116087351, 0.9674003013992828, ''),
#   Text(0.5220279906202548, 0.9682390082045752, ''),
#   Text(0.5205365678095301, 0.9690416304643855, ''),
#   Text(0.5190260274420894, 0.9698515261820665, ''),
#   Text(0.5174515809204437, 0.9706924648944864, ''),
#   Text(0.5157503650318855, 0.9715974274201621, ''),
#   Text(0.5139937681144269, 0.9725278434777757, ''),
#   Text(0.5123431903855581, 0.9733984052100908, ''),
#   Text(0.5107360504326891, 0.9742426221370207, ''),
#   Text(0.5094511343782744, 0.97491514588742, ''),
#   Text(0.5081923165955735, 0.9755719191085938, ''),
#   Text(0.5066536121781576, 0.9763719154435082, ''),
#   Text(0.5050686013204677, 0.9771927690891836, ''),
#   Text(0.5035724291194857, 0.9779646254495613, ''),
#   Text(0.5023999042747668, 0.978567491890419, ''),
#   Text(0.5012898508385032, 0.9791366020358504, ''),
#   Text(0.4999894570091194, 0.9798012772392809, ''),
#   Text(0.49856162214416944, 0.9805285864904575, ''),
#   Text(0.49712368234957127, 0.981258398408494, ''),
#   Text(0.49573899575241936, 0.9819586794210756, ''),
#   Text(0.4944167409707315, 0.9826250995409597, ''),
#   Text(0.493129852933194, 0.9832715536137954, ''),
#   Text(0.4917332584887746, 0.9839707325403597, ''),
#   Text(0.49029028002356173, 0.9846905307325838, ''),
#   Text(0.48880082100722483, 0.9854307471266883, ''),
#   Text(0.48750117319595504, 0.986074341078079, ''),
#   Text(0.486710063621355, 0.9864650596801171, ''),
#   Text(0.4856729633878359, 0.9869760750059132, ''),
#   Text(0.484207373097949, 0.9876959146607744, ''),
#   Text(0.4827953930455188, 0.988386871854348, ''),
#   Text(0.48138242700937955, 0.9890758105254417, ''),
#   Text(0.479822465958736, 0.9898335219425931, ''),
#   Text(0.47812431216954265, 0.990654905662109, ''),
#   Text(0.4765892871352088, 0.9913942966287196, ''),
#   Text(0.47522690923929417, 0.9920480758183385, ''),
#   Text(0.47372634248723244, 0.992765507274336, ''),
#   Text(0.47205065119090855, 0.9935633762927453, ''),
#   Text(0.47045612457067804, 0.994319382720632, ''),
#   Text(0.46896130291561106, 0.995025274235631, ''),
#   Text(0.4675939441609378, 0.9956685710536504, ''),
#   Text(0.4662073313507979, 0.9963185856917293, ''),
#   Text(0.46480143121545614, 0.9969752401840599, ''),
#   Text(0.46354176828555016, 0.9975615414873938, ''),
#   Text(0.46229977111442555, 0.9981377267830075, ''),
#   Text(0.4610754735463168, 0.9987038638625766, ''),
#   Text(0.45996103659609594, 0.9992176163446305, ''),
#   Text(0.4587538520962947, 0.9997724256983742, ''),
#   Text(0.45749066082999806, 1.0003510859959777, ''),
#   Text(0.456549708550985, 1.0007808769266182, ''),
#   Text(0.4554329573324715, 1.0012895791804683, ''),
#   Text(0.45406624314930155, 1.0019100991767074, ''),
#   Text(0.45268019723440545, 1.0025371010749777, ''),
#   Text(0.45117304584057016, 1.0032162691598174, ''),
#   Text(0.4497481751527772, 1.0038558556619308, ''),
#   Text(0.44874837412893986, 1.0043031896377872, ''),
#   Text(0.448081592890316, 1.0046008591041904, ''),
#   Text(0.4472941664856902, 1.0049517046245915, ''),
#   Text(0.4463859692383572, 1.005355442849509, ''),
#   Text(0.4454588616848985, 1.0057665745819924, ''),
#   Text(0.4444942681197653, 1.0061932446645994, ''),
#   Text(0.4435292658814204, 1.0066189896414077, ''),
#   Text(0.4425081467407602, 1.0070682896745673, ''),
#   Text(0.44144012646274844, 1.0075369049064917, ''),
#   Text(0.44041807746683004, 1.0079840857079152, ''),
#   Text(0.43939557547550595, 1.0084302297395438, ''),
#   Text(0.4383447164942569, 1.0088874612768115, ''),
#   Text(0.43724685150966164, 1.009363755464247, ''),
#   Text(0.43614846899691884, 1.009838854962337, ''),
#   Text(0.4350681999707589, 1.0103047368859577, ''),
#   Text(0.43395015658781066, 1.010785467642573, ''),
#   Text(0.43276631549705585, 1.0112928933652716, ''),
#   Text(0.43156322384534956, 1.011806890579526, ''),
#   Text(0.43039685491731516, 1.0123035845423465, ''),
#   Text(0.4292205765480745, 1.0128028913207834, ''),
#   Text(0.42793160707806405, 1.0133481828392379, ''),
#   Text(0.4266232489549127, 1.0138997008832553, ''),
#   Text(0.42538900315710765, 1.014418156379805, ''),
#   Text(0.4241260546554634, 1.014946840855417, ''),
#   Text(0.422768822546445, 1.0155129357535002, ''),
#   Text(0.4213827305685698, 1.0160888712994431, ''),
#   Text(0.42001460076473096, 1.0166551702246165, ''),
#   Text(0.41866446703455457, 1.017211907147509, ''),
#   Text(0.41727606067246287, 1.0177822405552532, ''),
#   Text(0.4157835962933397, 1.018392852023902, ''),
#   Text(0.4142620532322108, 1.019012733606324, ''),
#   Text(0.4126831806194202, 1.0196531726199056, ''),
#   Text(0.41111272473700317, 1.0202873749877126, ''),
#   Text(0.4096071820676007, 1.0208927252158473, ''),
#   Text(0.4080536577476885, 1.0215146657776053, ''),
#   Text(0.40643322113144686, 1.0221604750530695, ''),
#   Text(0.40479290214534935, 1.0228111782595777, ''),
#   Text(0.40313266910902446, 1.0234666829443124, ''),
#   Text(0.40143360564239117, 1.0241342979614292, ''),
#   Text(0.3997617817327771, 1.0247880355789853, ''),
#   Text(0.39808889321192653, 1.0254390440690777, ''),
#   Text(0.3963771029340383, 1.026101940486236, ''),
#   Text(0.39469260827017555, 1.0267510628077703, ''),
#   Text(0.3929881057880233, 1.027404666482074, ''),
#   Text(0.39120669215763737, 1.0280842981055005, ''),
#   Text(0.389433588101336, 1.028757250501069, ''),
#   Text(0.38764983534669917, 1.0294307189683418, ''),
#   Text(0.3858269284093298, 1.0301153242788994, ''),
#   Text(0.38401231612790204, 1.0307931611444094, ''),
#   Text(0.3822250426280751, 1.0314572297424485, ''),
#   Text(0.38043662076827656, 1.0321181994221469, ''),
#   Text(0.3786280118536418, 1.0327830501319037, ''),
#   Text(0.3767801281306393, 1.0334586276411162, ''),
#   Text(0.3749310389979459, 1.0341308988691524, ''),
#   Text(0.37315707454825703, 1.034772341007715, ''),
#   Text(0.3713342808967557, 1.0354278593078754, ''),
#   Text(0.3693861512539886, 1.036124447767625, ''),
#   Text(0.36741759630025295, 1.0368241460966003, ''),
#   Text(0.36547641301079303, 1.0375099958712517, ''),
#   Text(0.3635435214414685, 1.0381888595134976, ''),
#   Text(0.3616189469788978, 1.0388607881645515, ''),
#   Text(0.3597218832235186, 1.039519199789078, ''),
#   Text(0.35784280104613286, 1.0401675488782842, ''),
#   Text(0.3559337619406277, 1.0408223465658262, ''),
#   Text(0.3539851156569402, 1.041486695975202, ''),
#   Text(0.3520448377184071, 1.042144151370539, ''),
#   Text(0.350151410291111, 1.0427818515255942, ''),
#   Text(0.348237587470731, 1.0434225331439633, ''),
#   Text(0.34624558335789063, 1.0440852436487904, ''),
#   Text(0.3442330534375183, 1.0447504988852998, ''),
#   Text(0.34211322011869727, 1.0454465766456056, ''),
#   Text(0.3399726888106455, 1.0461446223457156, ''),
#   Text(0.33794655090032083, 1.0468009021464286, ''),
#   Text(0.3358129139926222, 1.0474873205895068, ''),
#   Text(0.33366821899334403, 1.0481724665501426, ''),
#   Text(0.331638166770108, 1.04881653607357, ''),
#   Text(0.3295391400404436, 1.0494779441138367, ''),
#   Text(0.3274097478181575, 1.0501442077322765, ''),
#   Text(0.3252790085568251, 1.0508061508157864, ''),
#   Text(0.3230402922170239, 1.0514965380848098, ''),
#   Text(0.3216148909785072, 1.0519333923309417, ''),
#   Text(0.3210038237483066, 1.0521200241127275, ''),
#   Text(0.3203247331531736, 1.0523269764338212, ''),
#   Text(0.31961639655243484, 1.052542331241284, ''),
#   Text(0.3188982089307723, 1.0527601494836065, ''),
#   Text(0.31817016462192427, 1.0529804111874341, ''),
#   Text(0.31755848983851476, 1.053165041924333, ''),
#   Text(0.31687872552084045, 1.0533697704568363, ''),
#   Text(0.3159754059263314, 1.0536410882504963, ''),
#   Text(0.31507185402471005, 1.05391163140058, ''),
#   Text(0.31419722842499187, 1.0541727095927185, ''),
#   Text(0.31331266479977765, 1.0544359506750813, ''),
#   Text(0.31240843232884363, 1.0547042103878388, ''),
#   Text(0.3114942435669108, 1.05497456662456, ''),
#   Text(0.3105603625301381, 1.0552498572495281, ''),
#   Text(0.30957757923618917, 1.0555385935314072, ''),
#   Text(0.3085750584012711, 1.0558321047082497, ''),
#   Text(0.3076014709371117, 1.0561161560535497, ''),
#   Text(0.30662762199702914, 1.05639930964974, ''),
#   Text(0.3056535124088419, 1.0566815652561268, ''),
#   Text(0.3046499079321087, 1.0569713494683561, ''),
#   Text(0.30356804606213783, 1.0572825740595633, ''),
#   Text(0.30245661371708243, 1.057601057497011, ''),
#   Text(0.30136435476028256, 1.0579128157272313, ''),
#   Text(0.30030104420947445, 1.058215140151897, ''),
#   Text(0.29917887402579085, 1.0585329476859282, ''),
#   Text(0.29797826758988805, 1.0588715465268341, ''),
#   Text(0.2967772779428539, 1.0592087836195612, ''),
#   Text(0.29552706234755755, 1.0595582831634243, ''),
#   Text(0.29425689088970497, 1.059911733194762, ''),
#   Text(0.29301562289286565, 1.0602555563356912, ''),
#   Text(0.29173483890440866, 1.0606086855053654, ''),
#   Text(0.2904536293428526, 1.0609602674942946, ''),
#   Text(0.2892013512614059, 1.061302303035557, ''),
#   Text(0.2879290941071586, 1.0616481699539784, ''),
#   Text(0.28665642331963975, 1.061992511729528, ''),
#   Text(0.28535395697144844, 1.0623432210169823, ''),
#   Text(0.284011870061135, 1.0627028077804148, ''),
#   Text(0.28269873362460657, 1.0630528801555659, ''),
#   Text(0.28140477431769484, 1.0633961411398893, ''),
#   Text(0.2800613606009117, 1.0637507388003857, ''),
#   Text(0.27866844563070875, 1.0641164867671984, ''),
#   Text(0.277265238739689, 1.0644829671660432, ''),
#   Text(0.27589100286933765, 1.0648399666314894, ''),
#   Text(0.2745555906550305, 1.0651850673193215, ''),
#   Text(0.27320009882738067, 1.0655335311479923, ''),
#   Text(0.27176554636222844, 1.0659003179521243, ''),
#   Text(0.2703206706430567, 1.0662676657495942, ''),
#   Text(0.2689343028616727, 1.0666181794551912, ''),
#   Text(0.2675376433405982, 1.0669693572899641, ''),
#   Text(0.26609132262400886, 1.067330973983331, ''),
#   Text(0.2646838885829693, 1.0676808695132636, ''),
#   Text(0.26331538232964785, 1.0680191989981227, ''),
#   Text(0.2619070432748873, 1.0683654340547557, ''),
#   Text(0.26046868894468084, 1.0687170168381521, ''),
#   Text(0.25902000609875, 1.069069051296783, ''),
#   Text(0.2575807073002284, 1.0694167472163105, ''),
#   Text(0.2561310787546399, 1.069764866919822, ''),
#   Text(0.2546316484418479, 1.0701227610007122, ''),
#   Text(0.2531613267344814, 1.0704715515351342, ''),
#   Text(0.25173001797141975, 1.0708090390224154, ''),
#   Text(0.250278507811302, 1.0711492279452701, ''),
#   Text(0.24878702219737367, 1.0714966250932214, ''),
#   Text(0.24724564321386758, 1.0718533444048028, ''),
#   Text(0.24567409599899498, 1.0722146420167358, ''),
#   Text(0.24411190979573927, 1.0725713848019054, ''),
#   Text(0.24257888200577096, 1.072919142342437, ''),
#   Text(0.24105525410093884, 1.0732624862867108, ''),
#   Text(0.239501444869774, 1.0736102914490393, ''),
#   Text(0.2379372321336975, 1.073958040877089, ''),
#   Text(0.23639232419476547, 1.074299152499804, ''),
#   Text(0.23480729528070357, 1.0746467019830102, ''),
#   Text(0.23329113343046515, 1.074976858849868, ''),
#   Text(0.2318141635908085, 1.0752963282550043, ''),
#   Text(0.23029708828745976, 1.0756222622864953, ''),
#   Text(0.2287497945708009, 1.075952383464908, ''),
#   Text(0.22714248873160578, 1.0762928457500833, ''),
#   Text(0.22552474987260412, 1.076632986302621, ''),
#   Text(0.22385685408998954, 1.0769810160243927, ''),
#   Text(0.22222815202779256, 1.077318267015979, ''),
#   Text(0.22062874913057492, 1.0776469528825654, ''),
#   Text(0.21900898263790927, 1.0779773028797537, ''),
#   Text(0.21736883793427386, 1.0783092266576892, ''),
#   Text(0.21567846577253189, 1.078648598665018, ''),
#   Text(0.2140273557420055, 1.078977428398799, ''),
#   Text(0.21242549899142094, 1.0792939392854228, ''),
#   Text(0.21077340503610564, 1.07961778965034, ''),
#   Text(0.20905111912722518, 1.0799526052524966, ''),
#   Text(0.20729842137188007, 1.080290407481584, ''),
#   Text(0.20555514088279392, 1.0806234700656168, ''),
#   Text(0.20379139276307323, 1.0809574775335462, ''),
#   Text(0.20208691728439798, 1.0812774287214586, ''),
#   Text(0.20039191163488365, 1.0815928447208392, ''),
#   Text(0.19859666328032327, 1.0819239184591134, ''),
#   Text(0.19679088974134984, 1.0822538268423023, ''),
#   Text(0.1949945494036313, 1.0825789235445493, ''),
#   Text(0.19318768791751195, 1.0829028198490787, ''),
#   Text(0.19132036542443834, 1.0832342857267119, ''),
#   Text(0.1894524742255823, 1.0835625316564823, ''),
#   Text(0.18761399947249965, 1.0838823677880978, ''),
#   Text(0.18577498478112314, 1.084199084591743, ''),
#   Text(0.18394543439029234, 1.0845109852679993, ''),
#   Text(0.18213536399704705, 1.084816440316823, ''),
#   Text(0.180254754010303, 1.0851305099649007, ''),
#   Text(0.17834357974942552, 1.085446252728416, ''),
#   Text(0.17647189417987524, 1.0857521220631194, ''),
#   Text(0.17461971035592777, 1.0860515442442003, ''),
#   Text(0.1727670185129408, 1.086347806788484, ''),
#   ...])

# %%
sns.pairplot(df)

# %%
n=df.corr()
sns.heatmap(n,annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(d)
# Out:
# <Axes: ylabel='Whole weight'>

# %%
x=df.drop('Rings',axis=1)
y=df['Rings']

# %%
x
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell weight
# 0           0.1500
# 1           0.0700
# 2           0.2100
# 3           0.1550
# 4           0.0550
# ...            ...
# 4172        0.2490
# 4173        0.2605
# 4174        0.3080
# 4175        0.2960
# 4176        0.4950
#
# [4177 rows x 7 columns]

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=95)

# %%
x_train
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 3910   0.455     0.355   0.135        0.4745          0.1865          0.0935
# 517    0.280     0.200   0.080        0.0915          0.0330          0.0215
# 714    0.350     0.255   0.080        0.1915          0.0800          0.0385
# 2603   0.620     0.510   0.175        1.2705          0.5415          0.3230
# 1939   0.625     0.445   0.160        1.0900          0.4600          0.2965
# ...      ...       ...     ...           ...             ...             ...
# 4116   0.625     0.480   0.160        1.2415          0.6575          0.2625
# 1007   0.610     0.470   0.150        1.1625          0.5650          0.2580
# 352    0.570     0.460   0.140        0.9535          0.4465          0.2065
# 1794   0.575     0.450   0.130        0.8145          0.4030          0.1715
# 3603   0.420     0.325   0.110        0.3250          0.1245          0.0755
#
#       Shell weight
# 3910        0.1680
# 517         0.0300
# 714         0.0630
# 2603        0.3225
# 1939        0.3040
# ...            ...
# 4116        0.2785
# 1007        0.3085
# 352         0.2450
# 1794        0.2130
# 3603        0.1025
#
# [3550 rows x 7 columns]

# %%
x_test
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 2403   0.290     0.225   0.080        0.1295          0.0535          0.0260
# 1340   0.585     0.465   0.155        0.9145          0.4555          0.1965
# 424    0.260     0.200   0.070        0.0920          0.0370          0.0200
# 3451   0.550     0.440   0.155        0.9155          0.3645          0.1950
# 3302   0.710     0.575   0.175        1.5550          0.6465          0.3705
# ...      ...       ...     ...           ...             ...             ...
# 80     0.575     0.445   0.140        0.9410          0.3845          0.2520
# 1014   0.625     0.500   0.165        1.2880          0.5730          0.3035
# 1615   0.550     0.425   0.150        0.7665          0.3390          0.1760
# 2640   0.465     0.355   0.105        0.4420          0.2085          0.0975
# 3389   0.565     0.465   0.150        1.1285          0.3770          0.3525
#
#       Shell weight
# 2403        0.0450
# 1340        0.2350
# 424         0.0300
# 3451        0.2500
# 3302        0.5200
# ...            ...
# 80          0.2850
# 1014        0.3150
# 1615        0.2100
# 2640        0.1185
# 3389        0.3300
#
# [627 rows x 7 columns]

# %%
y_train
# Out:
# 3910    13
# 517      5
# 714      9
# 2603     9
# 1939    11
#         ..
# 4116     9
# 1007    11
# 352     12
# 1794    10
# 3603     7
# Name: Rings, Length: 3550, dtype: int64

# %%
y_test
# Out:
# 2403    10
# 1340     9
# 424      6
# 3451     8
# 3302    15
#         ..
# 80       9
# 1014     9
# 1615     8
# 2640     7
# 3389    16
# Name: Rings, Length: 627, dtype: int64

# %%
from sklearn.svm import SVC
sng=SVC(kernel='rbf')
sng.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=sng.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.2759170653907496
