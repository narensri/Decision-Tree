# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/abalone.csv')

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.head(2)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
#
#    Shell weight  Rings
# 0          0.15     15
# 1          0.07      7

# %%
df.tail(3)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4174          0.2875         0.308      9
# 4175          0.2610         0.296     10
# 4176          0.3765         0.495     12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
--df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
a=df['Diameter']
sns.lineplot(a)
# Out:
# <Axes: ylabel='Diameter'>

# %%
b=df['Length']
c=df['Height']
sns.scatterplot(x=b,y=c,data=df)
# Out:
# <Axes: xlabel='Length', ylabel='Height'>

# %%
d=df['Whole weight']
sns.barplot(d)
# Out:
# <Axes: ylabel='Whole weight'>

# %%
sns.distplot(a)
# Out:
# <ipython-input-15-f134c0697e25>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a)
# <Axes: xlabel='Diameter', ylabel='Density'>

# %%
sns.boxplot(c)
# Out:
# <Axes: ylabel='Height'>

# %%
from sklearn.preprocessing import LabelEncoder
tip=LabelEncoder()
df['Sex']=tip.fit_transform(df['Sex'])

# %%
d=df.corr()
sns.heatmap(d,annot=True)
# Out:
# <Axes: >

# %%
x=df.drop(['Rings'],axis=1)
y=df['Rings']

# %%
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# 3             0.1140        0.1550
# 4             0.0395        0.0550
# ...              ...           ...
# 4172          0.2390        0.2490
# 4173          0.2145        0.2605
# 4174          0.2875        0.3080
# 4175          0.2610        0.2960
# 4176          0.3765        0.4950
#
# [4177 rows x 8 columns]

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=99)

# %%
x_train
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 3069    2   0.655     0.540   0.165        1.4030          0.6955
# 2653    1   0.520     0.395   0.135        0.6330          0.2985
# 2587    0   0.570     0.445   0.150        0.9950          0.5040
# 134     1   0.265     0.200   0.065        0.0975          0.0400
# 1129    2   0.560     0.415   0.145        0.8520          0.4300
# ...   ...     ...       ...     ...           ...             ...
# 55      0   0.500     0.400   0.140        0.6615          0.2565
# 3457    0   0.610     0.495   0.175        1.2635          0.5300
# 1768    1   0.435     0.300   0.120        0.5965          0.2590
# 1737    0   0.670     0.550   0.155        1.5660          0.8580
# 3240    2   0.555     0.435   0.135        0.8580          0.3770
#
#       Viscera weight  Shell weight
# 3069          0.2385        0.4200
# 2653          0.1295        0.1750
# 2587          0.1850        0.2505
# 134           0.0205        0.0280
# 1129          0.1885        0.2050
# ...              ...           ...
# 55            0.1755        0.2200
# 3457          0.3150        0.3455
# 1768          0.1390        0.1645
# 1737          0.3390        0.3540
# 3240          0.1585        0.2900
#
# [3341 rows x 8 columns]

# %%
x_test
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 2063    2   0.525     0.385   0.100        0.5115          0.2460
# 600     1   0.535     0.420   0.145        0.9260          0.3980
# 1790    0   0.550     0.380   0.165        1.2050          0.5430
# 1535    1   0.305     0.225   0.090        0.1465          0.0630
# 1936    2   0.625     0.495   0.155        1.0485          0.4870
# ...   ...     ...       ...     ...           ...             ...
# 329     1   0.360     0.280   0.090        0.2255          0.0885
# 1613    1   0.550     0.420   0.135        0.8160          0.3995
# 1287    1   0.505     0.405   0.130        0.6015          0.3015
# 217     1   0.405     0.300   0.120        0.3240          0.1265
# 3359    1   0.580     0.445   0.170        1.1780          0.3935
#
#       Viscera weight  Shell weight
# 2063          0.1005        0.1455
# 600           0.1965        0.2500
# 1790          0.2940        0.3345
# 1535          0.0340        0.0415
# 1936          0.2120        0.3215
# ...              ...           ...
# 329           0.0400        0.0900
# 1613          0.1485        0.2300
# 1287          0.1100        0.1800
# 217           0.0700        0.1100
# 3359          0.2165        0.3150
#
# [836 rows x 8 columns]

# %%
y_train
# Out:
# 3069    11
# 2653     9
# 2587     9
# 134      7
# 1129     8
#         ..
# 55       8
# 3457    10
# 1768     8
# 1737    10
# 3240    15
# Name: Rings, Length: 3341, dtype: int64

# %%
y_test
# Out:
# 2063     8
# 600     17
# 1790    10
# 1535     6
# 1936    11
#         ..
# 329      8
# 1613    12
# 1287     8
# 217      7
# 3359    20
# Name: Rings, Length: 836, dtype: int64

# %%
from sklearn.naive_bayes import MultinomialNB
hit=MultinomialNB()
hit.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=hit.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.14952153110047847
